# %% [markdown]
# # 1. Introducción

# %% [markdown]
# ## 1). ¿Qué es dbt?
#
# DBT (data build tool) es una herramienta de código abierto para la transformación de datos, ideal para modelar datos en almacenes de datos (data warehouses). Permite a los profesionales de datos que conocen SQL transformar datos de manera más eficiente. En un nivel más granular, dbt proporciona un marco de desarrollo que combina SQL modular con las mejores prácticas de ingeniería de software, creando una experiencia de transformación de datos más eficiente, rápida y confiable.
#
# *   **SQL Modular:** Descompone el código SQL en partes más pequeñas y reutilizables para facilitar su mantenimiento, prueba y reutilización.
#
# *   **Mejores Prácticas:** Integra control de versiones, documentación, DevOps y otras prácticas recomendadas.
#
# **Puntos Clave:**
#
# *   DBT es *solo* una herramienta de transformación. No gestiona el movimiento de datos fuera del almacén al que se conecta. Forma parte del componente "transformar" en los procesos ETL (Extract, Transform, Load) y ELT (Extract, Load, Transform). Requiere combinarse con otras herramientas para crear pipelines ETL/ELT completos.
#
# *   Creada para mejorar el flujo de trabajo de los analistas de datos, incorporando prácticas de ingeniería de software.
#
# *   Originalmente de código abierto (dbt Core), ahora también existe una versión comercial (dbt Cloud) con funcionalidades adicionales.
#
# *   DBT Core es la base del código y es gratuita. dbt Cloud ofrece un IDE, programación de tareas y otras características.
#
# **Características Importantes:**
#
# 1.  **Computación:** DBT no realiza los cálculos, sino que utiliza la capacidad de cómputo de tu almacén de datos (ej. AWS Redshift).
#
# 2.  **SQL:** Cada modelo en dbt (excepto los modelos Python) se escribe y compila como una sentencia SQL SELECT, incluso si se usa Jinja (un lenguaje de plantillas).
#
# 3.  **Creación de Objetos:** DBT se encarga de la creación de objetos de la base de datos (tablas, vistas, etc.), eliminando la necesidad de crearlos manualmente.

# %% [markdown]
# ## 2). ¿Qué es un "Analytics Engineer" (Ingeniero de Analítica)?
#
# El término "Ingeniero de Analítica" se utiliza a menudo en el contexto de dbt para describir a sus usuarios.  Este rol combina aspectos del Ingeniero de Datos tradicional y del Analista de Datos, proporcionando datasets limpios y modelados a los usuarios de negocio.
#
# Mientras que los Analistas de Datos se centran en el análisis de datos y los Ingenieros de Datos en la construcción de infraestructura y la gestión de datos (extracción, carga y transformación), el Ingeniero de Analítica utiliza dbt para unir estos dos mundos, aplicando sus habilidades en SQL.
#
# Si bien el concepto de combinar estas responsabilidades no es nuevo, dbt proporciona las herramientas para que sea mucho más eficiente.  Este nuevo título ha generado mucha atención, aumentando el conocimiento de la marca y creando una comunidad de usuarios de dbt.
#
# Aunque dbt se promociona mucho entre los Analistas de Datos, también es una excelente herramienta para Ingenieros de Datos.  Su capacidad para modelar datos utilizando SQL y Python la convierte en una herramienta valiosa para cualquier persona en este rol.  Tanto dbt Core (código abierto) como dbt Cloud (comercial) ofrecen opciones para diferentes necesidades y niveles de experiencia.

# %% [markdown]
# ## 3). El Rol de dbt en el "Modern Data Stack" (Arquitectura Moderna de Datos)
#
# En la actualidad, el enfoque ELT (Extract, Load, Transform) se ha vuelto predominante en el diseño de almacenes de datos, especialmente en la nube, debido al poder de las bases de datos analíticas modernas como Snowflake, Synapse, Databricks, BigQuery y MotherDuck. Estas plataformas ofrecen velocidad, escalabilidad y la capacidad de manejar transformaciones a nivel de base de datos.
#
# **Ventajas de ELT:**
#
# *   **Minimiza la latencia de red:** Al cargar los datos en bruto primero, se evita la transferencia repetida de grandes volúmenes de datos, ahorrando tiempo y recursos.
#
# *   **Flexibilidad y eficiencia:** Si se producen errores o cambian los requisitos, se pueden ajustar las transformaciones sin necesidad de recargar los datos desde el origen.
#
# *   **Almacenamiento económico:** El bajo costo del almacenamiento en la nube permite guardar una copia de los datos en bruto sin grandes costos, facilitando la reutilización para múltiples proyectos.
#
# **Pasos de un Almacén de Datos ELT con dbt:**
#
# 1.  **Definición del Cargador de Datos:** Seleccionar una herramienta para la ingesta de datos desde las fuentes al almacén (ej. Fivetran, Azure Data Factory, AWS Glue). DBT no cubre esta etapa, pero es crucial para su funcionamiento.
#
# 2.  **Carga de Datos en Bruto:** Ingestar los datos sin modificar en el almacén (data warehouse o data lake).  Es importante que los datos en bruto residan en el mismo sistema donde dbt realizará las transformaciones.
#
# 3.  **Snapshot de Datos en Bruto:** Extraer una copia de los datos en bruto para trabajar con ellos sin modificar los originales. Este paso puede combinarse con transformaciones iniciales y lógica incremental.
#
# 4.  **Transformación de Datos:**  Etapa central de dbt.  Aquí se normaliza/desnormaliza, limpia y modela la data para análisis, machine learning, etc.
#
# 5.  **Validación de Datos:**  DBT incorpora pruebas para asegurar la precisión de los datos y la correcta aplicación del modelo.
#
# 6.  **Despliegue:**  DBT Cloud facilita la automatización del despliegue mediante CI/CD.  DBT Core se puede integrar con otras herramientas como GitHub Actions.
#
# 7.  **Documentación:**  DBT genera automáticamente documentación a partir de descripciones y metadatos, simplificando el mantenimiento y la comprensión del proyecto.
#
# 8.  **Mejores Prácticas de Ingeniería de Software:**  DBT integra control de versiones, alertas y logging.
#
# 9.  **Entrega de Datos Transformados:**  Finalmente, los datos transformados se ponen a disposición de los usuarios de negocio y otros equipos de datos.
#
#
# DBT, aunque se centra en la transformación, se integra en un ecosistema más amplio.

# %% [markdown]
# ## 4). Habilidades Necesarias para Usar dbt
#
# DBT es un framework que requiere ciertas habilidades para su uso efectivo. Si bien es relativamente fácil de aprender, especialmente para aquellos con experiencia en datos, es importante comprender las habilidades clave que contribuyen al éxito de un Ingeniero de Analítica.
#
# A continuación, se detallan las habilidades técnicas principales, junto con una puntuación de experiencia (1-5, donde 5 indica la mayor necesidad de experiencia previa):
#
# **1. SQL (Puntuación: 4/5):** La habilidad más importante.  Se requiere un manejo cómodo de sentencias `SELECT`.  Si bien no es necesario un conocimiento avanzado de SQL para comenzar,  se recomienda familiarizarse con CTEs (Common Table Expressions) y funciones de ventana para un uso más efectivo de dbt.
#
# **2. Jinja (Puntuación: 2/5):** Jinja es un lenguaje de plantillas utilizado en Python.  Extiende las capacidades de SQL, permitiendo operaciones más complejas.  Si bien la experiencia previa con Python es útil, no es esencial, ya que los conceptos básicos de Jinja son fáciles de aprender.  Este libro dedica un capítulo completo a Jinja.
#
# **3. YAML (Puntuación: 2/5):**  YAML se utiliza para la configuración del proyecto dbt.  Es un lenguaje legible y fácil de aprender, por lo que no se requiere experiencia previa.
#
# **4. Python (Puntuación: 1/5):**  DBT soporta Python para scripts y plugins personalizados.  Si bien no es esencial para la mayoría de los casos de uso, puede ser útil para ciertas funcionalidades. Este libro abordará la creación de modelos Python con dbt.
#
# **5. Modelado de Datos (Puntuación: 1/5 o 4/5):**  Es importante comprender las diferentes metodologías de modelado de datos (Data Vault, Dimensional, etc.) y tener un plan.  La puntuación de experiencia varía según la responsabilidad en el diseño del modelo. Si el diseño lo proporciona otro miembro del equipo, la necesidad de experiencia es menor (1/5). Si lideras el diseño e implementación, la experiencia es crucial (4/5).
#
# **6. Control de Versiones (Puntuación: 2/5):**  Es fundamental comprender los conceptos básicos del control de versiones (ej. Git) para trabajar en entornos colaborativos. DBT está diseñado para integrarse con sistemas de control de versiones.  Si bien la experiencia previa es útil, dbt Cloud facilita la configuración y el uso del control de versiones.

# %% [markdown]
# ## 5). Beneficios de dbt
#
# 1.  **Optimizado para la Transformación y Analítica de Datos:** Ofrece características como gestión de dependencias, construcciones incrementales de modelos y pruebas de datos, optimizando el rendimiento de los procesos de transformación.
#
# 2.  **Diseñado para Usuarios de SQL:**  Facilita el aprendizaje y uso para Analistas e Ingenieros de Datos, incluso sin experiencia en otros lenguajes de programación.
#
# 3.  **Código Abierto y Fuerte Comunidad:**  El acceso al código fuente y una comunidad activa facilitan la búsqueda de ayuda y recursos. El canal de Slack de dbt es un ejemplo de esto.
#
# 4.  **Entorno Colaborativo:**  Incluye funciones como control de versiones, documentación y pruebas,  promoviendo la colaboración efectiva entre analistas e ingenieros de datos.
#
# 5.  **Flexible y Compatible:** Funciona con una amplia variedad de fuentes de datos y bases de datos de destino, ideal para organizaciones que necesitan integrar datos de múltiples sistemas.

# %% [markdown]
# # 2. ¿Como utilizar DBT?

# %% [markdown]
# ## 1). Instalar DBT Core y DBT Duck db

# %%
pip install dbt-core dbt-duckdb
# Out:
# Requirement already satisfied: dbt-core in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (1.8.0)
# Collecting dbt-duckdb
#   Downloading dbt_duckdb-1.9.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: agate<1.10,>=1.7.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (1.9.1)
# Requirement already satisfied: Jinja2<4,>=3.1.3 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (3.1.4)
# Requirement already satisfied: mashumaro<4.0,>=3.9 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from mashumaro[msgpack]<4.0,>=3.9->dbt-core) (3.13.1)
# Requirement already satisfied: logbook<1.6,>=1.5 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (1.5.3)
# Requirement already satisfied: click<9.0,>=8.0.2 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (8.1.7)
# Requirement already satisfied: networkx<4.0,>=2.3 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (3.3)
# Requirement already satisfied: protobuf<5,>=4.0.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (4.25.5)
# Requirement already satisfied: requests<3.0.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (2.32.3)
# Requirement already satisfied: pathspec<0.13,>=0.9 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (0.12.1)
# Requirement already satisfied: sqlparse<0.6.0,>=0.5.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (0.5.1)
# Requirement already satisfied: dbt-extractor<=0.6,>=0.5.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (0.5.1)
# Requirement already satisfied: minimal-snowplow-tracker<0.1,>=0.0.2 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (0.0.2)
# Requirement already satisfied: dbt-semantic-interfaces<0.6,>=0.5.1 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (0.5.1)
# Requirement already satisfied: dbt-common<2.0,>=1.0.2 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (1.10.0)
# Requirement already satisfied: dbt-adapters<2.0,>=0.1.0a2 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (1.7.0)
# Requirement already satisfied: packaging>20.9 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (24.1)
# Requirement already satisfied: pytz>=2015.7 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (2024.2)
# Requirement already satisfied: pyyaml>=6.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (6.0.2)
# Requirement already satisfied: daff>=1.3.46 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (1.3.46)
# Requirement already satisfied: typing-extensions>=4.4 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-core) (4.12.2)
# Requirement already satisfied: duckdb>=1.0.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-duckdb) (1.1.2)
# Requirement already satisfied: Babel>=2.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from agate<1.10,>=1.7.0->dbt-core) (2.16.0)
# Requirement already satisfied: isodate>=0.5.4 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from agate<1.10,>=1.7.0->dbt-core) (0.6.1)
# Requirement already satisfied: leather>=0.3.2 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from agate<1.10,>=1.7.0->dbt-core) (0.4.0)
# Requirement already satisfied: parsedatetime!=2.5,>=2.1 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from agate<1.10,>=1.7.0->dbt-core) (2.6)
# Requirement already satisfied: python-slugify>=1.2.1 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from agate<1.10,>=1.7.0->dbt-core) (8.0.4)
# Requirement already satisfied: pytimeparse>=1.1.5 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from agate<1.10,>=1.7.0->dbt-core) (1.1.8)
# Requirement already satisfied: colorama<0.5,>=0.3.9 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-common<2.0,>=1.0.2->dbt-core) (0.4.6)
# Requirement already satisfied: deepdiff<8.0,>=7.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-common<2.0,>=1.0.2->dbt-core) (7.0.1)
# Requirement already satisfied: jsonschema<5.0,>=4.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-common<2.0,>=1.0.2->dbt-core) (4.23.0)
# Requirement already satisfied: python-dateutil<3.0,>=2.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-common<2.0,>=1.0.2->dbt-core) (2.9.0.post0)
# Requirement already satisfied: importlib-metadata<7,>=6.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-semantic-interfaces<0.6,>=0.5.1->dbt-core) (6.11.0)
# Requirement already satisfied: more-itertools<11.0,>=8.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-semantic-interfaces<0.6,>=0.5.1->dbt-core) (10.5.0)
# Requirement already satisfied: pydantic<3,>=1.10 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from dbt-semantic-interfaces<0.6,>=0.5.1->dbt-core) (2.9.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from Jinja2<4,>=3.1.3->dbt-core) (2.1.5)
# Requirement already satisfied: msgpack>=0.5.6 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from mashumaro[msgpack]<4.0,>=3.9->dbt-core) (1.1.0)
# Requirement already satisfied: six<2.0,>=1.9.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from minimal-snowplow-tracker<0.1,>=0.0.2->dbt-core) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from requests<3.0.0->dbt-core) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from requests<3.0.0->dbt-core) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from requests<3.0.0->dbt-core) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from requests<3.0.0->dbt-core) (2024.8.30)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from deepdiff<8.0,>=7.0->dbt-common<2.0,>=1.0.2->dbt-core) (4.1.0)
# Requirement already satisfied: zipp>=0.5 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from importlib-metadata<7,>=6.0->dbt-semantic-interfaces<0.6,>=0.5.1->dbt-core) (3.20.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.2->dbt-core) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.2->dbt-core) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.2->dbt-core) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.2->dbt-core) (0.20.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from pydantic<3,>=1.10->dbt-semantic-interfaces<0.6,>=0.5.1->dbt-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from pydantic<3,>=1.10->dbt-semantic-interfaces<0.6,>=0.5.1->dbt-core) (2.23.4)
# Requirement already satisfied: text-unidecode>=1.3 in /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/lib/python3.11/site-packages (from python-slugify>=1.2.1->agate<1.10,>=1.7.0->dbt-core) (1.3)
# Downloading dbt_duckdb-1.9.0-py3-none-any.whl (62 kB)
# Installing collected packages: dbt-duckdb
# Successfully installed dbt-duckdb-1.9.0
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2). Cambiar al directorio en donde quiero iniciar el proyecto

# %%
import os

# Cambiar el directorio de trabajo a dos niveles arriba
os.chdir(os.path.join(os.getcwd(), "../.."))

# Verificar el nuevo directorio de trabajo
print("El nuevo directorio de trabajo es:", os.getcwd())
# Out:
# El nuevo directorio de trabajo es: /home/juan/UCCuyo/BaseDeDatos2024

# %% [markdown]
# ## 3). En la terminal poner el comando "dbt init"
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4). Elegir el nombre del proyecto DBT
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5). Elegir la base de datos a utilizar:
#
#  En este caso, vamos a usar DuckDB, pero podríamos utilizar también Postgres
#
#  ![image.png](attachment:image.png)

# %% [markdown]
# **Nota**: Según la última linea de código, el archivo "profiles.yml" fue creado en "/home/juan/.dbt/profiles.yml#
#
# ```bash
# 00:01:04  Profile ml_transformations written to /home/juan/.dbt/profiles.yml using target's sample configuration. Once updated, you'll be able to start developing with dbt.
# ```

# %% [markdown]
# ## 6). Crear una base de datos "DuckDB"

# %%
import duckdb 

base = duckdb.connect('mercado_libre.duckdb')

# %%
base.sql('''
SELECT *
FROM information_schema.tables
''')
# Out:
# ┌───────────────┬──────────────┬────────────┬────────────┬──────────────────────────────┬──────────────────────┬───────────────────────────┬──────────────────────────┬────────────────────────┬────────────────────┬──────────┬───────────────┬───────────────┐
# │ table_catalog │ table_schema │ table_name │ table_type │ self_referencing_column_name │ reference_generation │ user_defined_type_catalog │ user_defined_type_schema │ user_defined_type_name │ is_insertable_into │ is_typed │ commit_action │ TABLE_COMMENT │
# │    varchar    │   varchar    │  varchar   │  varchar   │           varchar            │       varchar        │          varchar          │         varchar          │        varchar         │      varchar       │ varchar  │    varchar    │    varchar    │
# ├───────────────┴──────────────┴────────────┴────────────┴──────────────────────────────┴──────────────────────┴───────────────────────────┴──────────────────────────┴────────────────────────┴────────────────────┴──────────┴───────────────┴───────────────┤
# │                                                                                                                            0 rows                                                                                                                            │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
base.close()

# %% [markdown]
# ## 7). Cargar datos a la base:

# %% [markdown]
# ### a). Autenticarse en Mercadolibre (Con lo que vimos en la clase de ingesta)

# %%
import os
from dotenv import load_dotenv

load_dotenv()


CLIENT_ID = os.getenv('CLIENT_ID')
CLIENT_SECRET = os.getenv('CLIENT_SECRET')
REFRESH_TOKEN = os.getenv('REFRESH_TOKEN')  

payload = {
    "grant_type": "refresh_token",
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
    "refresh_token": REFRESH_TOKEN
}

response = requests.post("https://api.mercadolibre.com/oauth/token", data=payload)

oauth_response = response.json()

ACCESS_TOKEN = oauth_response['access_token']
USER_ID = oauth_response['user_id']

# %% [markdown]
# ### b). Descargar datos desde Mercado Libre con DLT

# %%
from dlt.sources.rest_api import RESTAPIConfig, rest_api_source
from dlt.sources.helpers.rest_client.paginators import OffsetPaginator
import dlt

def transform_variations_data(file):
    file['variations_data'] = None
    return file

def extract_ml_query_to_duckdb(query, dataset_name, ACCESS_TOKEN):

    pipeline = dlt.pipeline(
        pipeline_name="mercado_libre",
        destination="duckdb",
        dataset_name=dataset_name,
    )


    meli_config: RESTAPIConfig = {
        "client": {
            "base_url": "https://api.mercadolibre.com",
            "headers": {
                "Authorization": f"Bearer {ACCESS_TOKEN}"
            },

            "paginator": OffsetPaginator(limit=50, offset=0, total_path='paging.total', maximum_offset=1000),


        },

        "resources": [
            {
                "name": "search",
                "endpoint": {
                    "path": "sites/MLA/search",  
                    "params": {
                        'q': f'{query}'
                    },
                    "data_selector": "results"
                },
                "processing_steps":[
                    {'map': transform_variations_data}
                ]
            },
            {
            "name": "seller",
            "endpoint":{
                'path':'users/{user_id}',
                'params':{
                    'user_id':{
                        'type':'resolve',
                        'resource':'search',
                        'field':'seller.id'
                    }
                }
                
            }
            }

        ],
    }


    # Crea la fuente de la API de MercadoLibre
    meli_source = rest_api_source(meli_config)

    # Ejecuta el pipeline para cargar los datos
    load_info = pipeline.run(meli_source)

    # Imprime información sobre la carga
    print(load_info)

# %%
extract_ml_query_to_duckdb('laptop', 'laptop', ACCESS_TOKEN)
# Out:
# Pipeline mercado_libre load step completed in 2.08 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset laptop
# The duckdb destination used duckdb:////home/juan/UCCuyo/BaseDeDatos2024/mercado_libre.duckdb location to store data
# Load package 1730421812.1861982 is LOADED and contains no failed jobs

# %%
extract_ml_query_to_duckdb('Mini PC', 'mini_pc', ACCESS_TOKEN)
# Out:
# Pipeline mercado_libre load step completed in 2.27 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset mini_pc
# The duckdb destination used duckdb:////home/juan/UCCuyo/BaseDeDatos2024/mercado_libre.duckdb location to store data
# Load package 1730423180.2282407 is LOADED and contains no failed jobs

# %%
extract_ml_query_to_duckdb('Computadora de Escritorio', 'pc', ACCESS_TOKEN)
# Out:
# Pipeline mercado_libre load step completed in 2.25 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset pc
# The duckdb destination used duckdb:////home/juan/UCCuyo/BaseDeDatos2024/mercado_libre.duckdb location to store data
# Load package 1730423395.639414 is LOADED and contains no failed jobs

# %% [markdown]
# ### c). Analizar los datos extraídos

# %%
base = duckdb.connect('mercado_libre.duckdb')

# %%
base.sql('''
SELECT *
FROM information_schema.tables
WHERE table_schema='laptop'
''')
# Out:
# ┌───────────────┬──────────────┬──────────────────────────────────────────────────────┬────────────┬──────────────────────────────┬──────────────────────┬───────────────────────────┬──────────────────────────┬────────────────────────┬────────────────────┬──────────┬───────────────┬───────────────┐
# │ table_catalog │ table_schema │                      table_name                      │ table_type │ self_referencing_column_name │ reference_generation │ user_defined_type_catalog │ user_defined_type_schema │ user_defined_type_name │ is_insertable_into │ is_typed │ commit_action │ TABLE_COMMENT │
# │    varchar    │   varchar    │                       varchar                        │  varchar   │           varchar            │       varchar        │          varchar          │         varchar          │        varchar         │      varchar       │ varchar  │    varchar    │    varchar    │
# ├───────────────┼──────────────┼──────────────────────────────────────────────────────┼────────────┼──────────────────────────────┼──────────────────────┼───────────────────────────┼──────────────────────────┼────────────────────────┼────────────────────┼──────────┼───────────────┼───────────────┤
# │ mercado_libre │ laptop       │ search                                               │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ laptop       │ search__attributes                                   │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ laptop       │ search__attributes__values                           │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ laptop       │ search__sale_price__conditions__context_restrictions │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ laptop       │ search__shipping__tags                               │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ laptop       │ search__variation_filters                            │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ laptop       │ seller                                               │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ laptop       │ _dlt_loads                                           │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ laptop       │ _dlt_pipeline_state                                  │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ laptop       │ _dlt_version                                         │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# ├───────────────┴──────────────┴──────────────────────────────────────────────────────┴────────────┴──────────────────────────────┴──────────────────────┴───────────────────────────┴──────────────────────────┴────────────────────────┴────────────────────┴──────────┴───────────────┴───────────────┤
# │ 10 rows                                                                                                                                                                                                                                                                                     13 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
base.sql('''
SELECT *
FROM laptop.search                                               
''')
# Out:
# ┌───────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────┬──────────────────────────────┬────────────────────┬─────────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬─────────────┬─────────┬─────────────┬───────────────┬────────────────────────────────────────────────────────────────┬─────────────┬───────────────┬───────────┬────────────────┬──────────────────────┬────────────────────┬──────────────────────────────────┬────────────────────────────────────┬──────────────────────────────────┬─────────────────────────┬─────────────────────────────────┬────────────────────────────┬──────────────────┬──────────────────────────────────────┬────────────────────────────────────┬────────────────────┬───────────────────┬─────────────────────┬──────────────────┬─────────────────────┬─────────────────────────┬─────────────────────────┬─────────────────────────┬────────────────┬──────────────────────────┬────────────────────────────┬────────────┬──────────────────────┬────────────────────────┬──────────────────────┬────────────────────┬───────────────────────────┬───────────────────────────────────────────────┬──────────────────────────────────────────────────┬─────────────────┬──────────────┬────────────────────┬────────────────┬────────────────────────────────────┬────────────────────────────────────────────┬─────────────────────────────────────┬───────────────────────────────────┬────────────────────────────────────────┬─────────────────────────────────┬────────────────────────────────────────────────────┬─────────────────────────────────────────┬──────────────────────────┬──────────────────────────────────────┬──────────────────────────────────────────────────┬──────────────────────────────────────────────────────┬──────────────────────────────┐
# │      id       │                                                          title                                                           │ condition │         thumbnail_id         │ catalog_product_id │ listing_type_id │                                                     sanitized_title                                                      │                                                                                              permalink                                                                                               │ buying_mode │ site_id │ category_id │   domain_id   │                           thumbnail                            │ currency_id │ order_backend │   price   │ original_price │ sale_price__price_id │ sale_price__amount │ sale_price__conditions__eligible │ sale_price__conditions__start_time │ sale_price__conditions__end_time │ sale_price__currency_id │ sale_price__payment_method_type │ sale_price__regular_amount │ sale_price__type │ sale_price__metadata__promotion_type │ sale_price__metadata__promotion_id │ available_quantity │ official_store_id │ official_store_name │ use_thumbnail_id │ accepts_mercadopago │ shipping__store_pick_up │ shipping__free_shipping │ shipping__logistic_type │ shipping__mode │ shipping__shipping_score │         stop_time          │ seller__id │   seller__nickname   │ installments__quantity │ installments__amount │ installments__rate │ installments__currency_id │ installments__metadata__meliplus_installments │ installments__metadata__additional_bank_interest │ catalog_listing │ inventory_id │    _dlt_load_id    │    _dlt_id     │ sale_price__metadata__funding_mode │ sale_price__metadata__discount_meli_amount │ sale_price__metadata__experiment_id │ sale_price__metadata__campaign_id │ sale_price__metadata__order_item_price │ sale_price__metadata__variation │ sale_price__metadata__campaign_discount_percentage │ sale_price__metadata__campaign_end_date │ original_price__v_double │ sale_price__regular_amount__v_double │ sale_price__metadata__order_item_price__v_double │ sale_price__metadata__discount_meli_amount__v_double │ installments__rate__v_double │
# │    varchar    │                                                         varchar                                                          │  varchar  │           varchar            │      varchar       │     varchar     │                                                         varchar                                                          │                                                                                               varchar                                                                                                │   varchar   │ varchar │   varchar   │    varchar    │                            varchar                             │   varchar   │     int64     │  double   │     int64      │       varchar        │       double       │             boolean              │      timestamp with time zone      │     timestamp with time zone     │         varchar         │             varchar             │           int64            │     varchar      │               varchar                │              varchar               │       int64        │       int64       │       varchar       │     boolean      │       boolean       │         boolean         │         boolean         │         varchar         │    varchar     │          int64           │  timestamp with time zone  │   int64    │       varchar        │         int64          │        double        │       int64        │          varchar          │                    boolean                    │                     boolean                      │     boolean     │   varchar    │      varchar       │    varchar     │              varchar               │                   int64                    │               varchar               │              varchar              │                 int64                  │             varchar             │                       double                       │        timestamp with time zone         │          double          │                double                │                      double                      │                        double                        │            double            │
# ├───────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────┼──────────────────────────────┼────────────────────┼─────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────┼─────────────┼───────────────┼────────────────────────────────────────────────────────────────┼─────────────┼───────────────┼───────────┼────────────────┼──────────────────────┼────────────────────┼──────────────────────────────────┼────────────────────────────────────┼──────────────────────────────────┼─────────────────────────┼─────────────────────────────────┼────────────────────────────┼──────────────────┼──────────────────────────────────────┼────────────────────────────────────┼────────────────────┼───────────────────┼─────────────────────┼──────────────────┼─────────────────────┼─────────────────────────┼─────────────────────────┼─────────────────────────┼────────────────┼──────────────────────────┼────────────────────────────┼────────────┼──────────────────────┼────────────────────────┼──────────────────────┼────────────────────┼───────────────────────────┼───────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────┼────────────────────┼────────────────┼────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────┼───────────────────────────────────┼────────────────────────────────────────┼─────────────────────────────────┼────────────────────────────────────────────────────┼─────────────────────────────────────────┼──────────────────────────┼──────────────────────────────────────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼──────────────────────────────┤
# │ MLA1424712885 │ Notebook Exo Smart T38 Intel N4020 4gb Ssd128gb Windows 11 Color Gris                                                    │ new       │ 620219-MLA54973743242_042023 │ MLA22826188        │ gold_pro        │ notebook-exo-smart-t38-intel-n4020-4gb-ssd128gb-windows-11-color-gris                                                    │ https://www.mercadolibre.com.ar/notebook-exo-smart-t38-intel-n4020-4gb-ssd128gb-windows-11-color-gris/p/MLA22826188#wid=MLA1424712885&sid=unknown                                                    │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_620219-MLA54973743242_042023-I.jpg │ ARS         │             1 │ 414399.26 │         559999 │                      │          414399.26 │ true                             │ 2024-10-28 00:00:00-03             │ 2024-11-27 23:59:59-03           │ ARS                     │ TMP                             │                     559999 │ promotion        │ custom                               │ OFFER-MLA1424712885-10200693227    │                250 │               341 │ EXO                 │ true             │ true                │ false                   │ true                    │ cross_docking           │ me2            │                       -1 │ 2044-04-28 01:00:00-03     │  180214913 │ EXO SA               │                     12 │             34533.27 │                  0 │ ARS                       │ false                                         │ false                                            │ true            │ LLEM57590    │ 1730421501.3225703 │ GCY1SBkSzYYtlA │ NULL                               │                                       NULL │ NULL                                │ NULL                              │                                   NULL │ NULL                            │                                               NULL │ NULL                                    │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                         NULL │
# │ MLA1867549266 │ Notebook Lenovo Ideapad 1 15iau7 Pantalla Táctil Fhd De 15,6 Pulgadas Core I3-1215u 8 Gb De Ram Ssd De 256 Gb Gris Nube  │ new       │ 736072-MLU76955229828_062024 │ MLA37834136        │ gold_pro        │ notebook-lenovo-ideapad-1-15iau7-pantalla-tactil-fhd-de-156-pulgadas-core-i3-1215u-8-gb-de-ram-ssd-de-256-gb-gris-nube   │ https://www.mercadolibre.com.ar/notebook-lenovo-ideapad-1-15iau7-pantalla-tactil-fhd-de-156-pulgadas-core-i3-1215u-8-gb-de-ram-ssd-de-256-gb-gris-nube/p/MLA37834136#wid=MLA1867549266&sid=unknown   │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_736072-MLU76955229828_062024-I.jpg │ ARS         │             2 │  889999.0 │        1313198 │                      │           889999.0 │ true                             │ 2024-10-24 00:00:00-03             │ 2024-11-23 23:59:59-03           │ ARS                     │ TMP                             │                    1313198 │ promotion        │ custom                               │ OFFER-MLA1867549266-10198602768    │                250 │              NULL │ NULL                │ true             │ true                │ false                   │ true                    │ cross_docking           │ me2            │                       -1 │ 2044-07-26 01:00:00-03     │  638528199 │ MULTI.HOGAR          │                      9 │             98888.78 │                  0 │ ARS                       │ false                                         │ false                                            │ true            │ NULL         │ 1730421501.3225703 │ nZOsXziZMoAYDA │ NULL                               │                                       NULL │ NULL                                │ NULL                              │                                   NULL │ NULL                            │                                               NULL │ NULL                                    │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                         NULL │
# │ MLA1449873737 │ Notebook Hp Intel Celeron 8gb De Ram 128gb Ssd Emmc 14-dq0760dx 14 Pulgadas Hd 1366 X 768 Intel Graphics Windows 11 Home │ new       │ 989135-MLU79195554187_092024 │ MLA40652709        │ gold_pro        │ notebook-hp-intel-celeron-8gb-de-ram-128gb-ssd-emmc-14-dq0760dx-14-pulgadas-hd-1366-x-768-intel-graphics-windows-11-home │ https://www.mercadolibre.com.ar/notebook-hp-intel-celeron-8gb-de-ram-128gb-ssd-emmc-14-dq0760dx-14-pulgadas-hd-1366-x-768-intel-graphics-windows-11-home/p/MLA40652709#wid=MLA1449873737&sid=unknown │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_989135-MLU79195554187_092024-I.jpg │ ARS         │             3 │  522899.0 │         808499 │                      │           522899.0 │ true                             │ 2024-10-22 00:00:00-03             │ 2024-10-31 23:59:00-03           │ ARS                     │ TMP                             │                     808499 │ promotion        │ marketplace_campaign                 │ OFFER-MLA1449873737-10197724725    │                250 │             96166 │ ESPACIO ELECTRONICA │ true             │ true                │ false                   │ true                    │ cross_docking           │ me2            │                       -1 │ 2044-09-08 01:00:00-03     │   31875925 │ ESPACIO ELECTRONICA  │                      6 │             87149.83 │                  0 │ ARS                       │ false                                         │ false                                            │ true            │ NULL         │ 1730421501.3225703 │ jSo+pMlakVKXiQ │ coupon                             │                                      16100 │ cm_med_uplift_P-MLA14287012         │ P-MLA14287012                     │                                 538999 │ 54584                           │                                              35.32 │ 2024-10-31 23:59:00-03                  │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                         NULL │
# │ MLA1805429012 │ Notebook Noblex N14x1010 14.1 Hd Intel Celeron 4gb/128gb Ssd                                                             │ new       │ 939222-MLU76657843660_062024 │ MLA37505961        │ gold_pro        │ notebook-noblex-n14x1010-141-hd-intel-celeron-4gb128gb-ssd                                                               │ https://www.mercadolibre.com.ar/notebook-noblex-n14x1010-141-hd-intel-celeron-4gb128gb-ssd/p/MLA37505961#wid=MLA1805429012&sid=unknown                                                               │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_939222-MLU76657843660_062024-I.jpg │ ARS         │             4 │  389999.0 │         585999 │                      │           389999.0 │ true                             │ 2024-10-28 15:40:00-03             │ 2024-10-31 23:59:00-03           │ ARS                     │ TMP                             │                     585999 │ promotion        │ marketplace_campaign                 │ OFFER-MLA1805429012-10200733736    │                100 │              1192 │ Noblex              │ true             │ true                │ false                   │ true                    │ cross_docking           │ me2            │                       -1 │ 2044-06-05 01:00:00-03     │  256324891 │ PILISAR 33709180849  │                      3 │            129999.67 │                  0 │ ARS                       │ false                                         │ false                                            │ true            │ NULL         │ 1730421501.3225703 │ 5TRAVuk7+KTsLQ │ coupon                             │                                      10000 │ cm_med_uplift_P-MLA14287012         │ P-MLA14287012                     │                                 399999 │ 54584                           │                                              33.45 │ 2024-10-31 23:59:00-03                  │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                         NULL │
# │ MLA1852464206 │ Notebook Lenovo Ideapad 1 4gb 128gb 14 Intel Celeron W11 Color Plateado                                                  │ new       │ 763058-MLU73905263055_012024 │ MLA29590978        │ gold_pro        │ notebook-lenovo-ideapad-1-4gb-128gb-14-intel-celeron-w11-color-plateado                                                  │ https://www.mercadolibre.com.ar/notebook-lenovo-ideapad-1-4gb-128gb-14-intel-celeron-w11-color-plateado/p/MLA29590978#wid=MLA1852464206&sid=unknown                                                  │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_763058-MLU73905263055_012024-I.jpg │ ARS         │             5 │  454399.0 │         504399 │                      │           454399.0 │ true                             │ 2024-10-21 00:00:00-03             │ 2024-10-31 23:00:00-03           │ ARS                     │ TMP                             │                     504399 │ promotion        │ marketplace_campaign                 │ OFFER-MLA1852464206-10197085595    │                100 │              NULL │ NULL                │ true             │ true                │ false                   │ true                    │ fulfillment             │ me2            │                       -1 │ 2044-07-14 01:00:00-03     │  318494504 │ ELECTRO-WORLD GROUP  │                      9 │             50488.78 │                  0 │ ARS                       │ false                                         │ false                                            │ true            │ UUCL27624    │ 1730421501.3225703 │ Qi1t+JCrYETfsQ │ coupon                             │                                      13632 │ cm_med_uplift_P-MLA14287012         │ P-MLA14287012                     │                                 468031 │ 54584                           │                                               9.91 │ 2024-10-31 23:00:00-03                  │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                         NULL │
# │ MLA1935942156 │ Notebook Lenovo Intel I5 1135g7 8gb 256gb 14'' Fhd Win 11 Color Gris                                                     │ new       │ 792579-MLA79550224248_102024 │ MLA22892509        │ gold_pro        │ notebook-lenovo-intel-i5-1135g7-8gb-256gb-14-fhd-win-11-color-gris                                                       │ https://www.mercadolibre.com.ar/notebook-lenovo-intel-i5-1135g7-8gb-256gb-14-fhd-win-11-color-gris/p/MLA22892509#wid=MLA1935942156&sid=unknown                                                       │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_792579-MLA79550224248_102024-I.jpg │ ARS         │             6 │ 831720.34 │           NULL │                      │          831720.34 │ true                             │ 2024-10-22 00:00:00-03             │ 2024-10-31 23:59:59-03           │ ARS                     │ TMP                             │                       NULL │ promotion        │ custom                               │ OFFER-MLA1935942156-10198015455    │                 50 │              NULL │ NULL                │ true             │ true                │ false                   │ true                    │ cross_docking           │ me2            │                       -1 │ 2044-10-10 18:16:03.932-03 │     110162 │ COMPUFANSTORE.COM.AR │                      6 │            138620.06 │                  0 │ ARS                       │ false                                         │ false                                            │ true            │ NULL         │ 1730421501.3225703 │ UkUV61jkYLl8bQ │ NULL                               │                                       NULL │ NULL                                │ NULL                              │                                   NULL │ NULL                            │                                               NULL │ NULL                                    │                967116.68 │                            967116.68 │                                             NULL │                                                 NULL │                         NULL │
# │ MLA1455651621 │ Notebook Asus Vivobook 14 Intel Core I3 1215u, 16gb De Ram, 128gb Ssd, Full Hd, Windows 11 Home                          │ new       │ 609477-MLU79075818282_092024 │ MLA40377483        │ gold_pro        │ notebook-asus-vivobook-14-intel-core-i3-1215u-16gb-de-ram-128gb-ssd-full-hd-windows-11-home                              │ https://www.mercadolibre.com.ar/notebook-asus-vivobook-14-intel-core-i3-1215u-16gb-de-ram-128gb-ssd-full-hd-windows-11-home/p/MLA40377483#wid=MLA1455651621&sid=unknown                              │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_609477-MLU79075818282_092024-I.jpg │ ARS         │             7 │  685999.0 │        1172999 │                      │           685999.0 │ true                             │ 2024-10-22 00:00:00-03             │ 2024-10-31 23:59:00-03           │ ARS                     │ TMP                             │                    1172999 │ promotion        │ marketplace_campaign                 │ OFFER-MLA1455651621-10198283399    │                250 │             96166 │ ESPACIO ELECTRONICA │ true             │ true                │ false                   │ true                    │ cross_docking           │ me2            │                       -1 │ 2044-10-12 01:00:00-03     │   31875925 │ ESPACIO ELECTRONICA  │                      6 │            114333.17 │                  0 │ ARS                       │ false                                         │ false                                            │ true            │ NULL         │ 1730421501.3225703 │ LECj9DmSQTRTfQ │ coupon                             │                                      40000 │ cm_med_uplift_P-MLA14287012         │ P-MLA14287012                     │                                 725999 │ 54584                           │                                              41.52 │ 2024-10-31 23:59:00-03                  │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                         NULL │
# │ MLA1426346197 │ Notebook Hp Intel Core I3 N305, Ddr4 8gb Ram, 256gb Ssd, Windows 11, Patalla 14  Hd, Moonlight Blue                      │ new       │ 725385-MLU78610636172_082024 │ MLA38756798        │ gold_pro        │ notebook-hp-intel-core-i3-n305-ddr4-8gb-ram-256gb-ssd-windows-11-patalla-14-hd-moonlight-blue                            │ https://www.mercadolibre.com.ar/notebook-hp-intel-core-i3-n305-ddr4-8gb-ram-256gb-ssd-windows-11-patalla-14-hd-moonlight-blue/p/MLA38756798#wid=MLA1426346197&sid=unknown                            │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_725385-MLU78610636172_082024-I.jpg │ ARS         │             8 │  805999.0 │         898999 │                      │           805999.0 │ true                             │ 2024-10-29 00:00:00-03             │ 2024-10-31 23:59:00-03           │ ARS                     │ TMP                             │                     898999 │ promotion        │ marketplace_campaign                 │ OFFER-MLA1426346197-10201111433    │                250 │              NULL │ NULL                │ true             │ true                │ false                   │ true                    │ cross_docking           │ me2            │                       -1 │ 2044-05-08 01:00:00-03     │  541407353 │ ELECTRO WORLD2       │                      9 │             89555.44 │                  0 │ ARS                       │ false                                         │ false                                            │ true            │ NULL         │ 1730421501.3225703 │ KZdY/mahSG38VQ │ coupon                             │                                      24180 │ cm_med_uplift_P-MLA14287012         │ P-MLA14287012                     │                                 830179 │ 54584                           │                                              10.34 │ 2024-10-31 23:59:00-03                  │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                         NULL │
# │ MLA1848679454 │ Netbook Exomate X5-s1441p Intel N4020c 4gb Ssd128gb 11,6 W11 Color Gris                                                  │ new       │ 716463-MLU75318989912_032024 │ MLA35101893        │ gold_pro        │ netbook-exomate-x5-s1441p-intel-n4020c-4gb-ssd128gb-116-w11-color-gris                                                   │ https://www.mercadolibre.com.ar/netbook-exomate-x5-s1441p-intel-n4020c-4gb-ssd128gb-116-w11-color-gris/p/MLA35101893#wid=MLA1848679454&sid=unknown                                                   │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_716463-MLU75318989912_032024-I.jpg │ ARS         │             9 │ 359999.28 │         499999 │                      │          359999.28 │ true                             │ 2024-10-28 00:00:00-03             │ 2024-11-27 23:59:59-03           │ ARS                     │ TMP                             │                     499999 │ promotion        │ custom                               │ OFFER-MLA1848679454-10200695677    │                200 │               341 │ EXO                 │ true             │ true                │ false                   │ true                    │ fulfillment             │ me2            │                       -1 │ 2044-07-12 01:00:00-03     │  180214913 │ EXO SA               │                     12 │             29999.94 │                  0 │ ARS                       │ false                                         │ false                                            │ true            │ OGMS99671    │ 1730421501.3225703 │ sqiQ1Nd1YF7HgA │ NULL                               │                                       NULL │ NULL                                │ NULL                              │                                   NULL │ NULL                            │                                               NULL │ NULL                                    │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                         NULL │
# │ MLA1914171672 │ Notebook Asus Vivobook 14 Intel Core I3 1215u 16gb De Ram 512gb Ssd Full Hd Windows 11 Home                              │ new       │ 758792-MLU78898463580_092024 │ MLA40553594        │ gold_pro        │ notebook-asus-vivobook-14-intel-core-i3-1215u-16gb-de-ram-512gb-ssd-full-hd-windows-11-home                              │ https://www.mercadolibre.com.ar/notebook-asus-vivobook-14-intel-core-i3-1215u-16gb-de-ram-512gb-ssd-full-hd-windows-11-home/p/MLA40553594#wid=MLA1914171672&sid=unknown                              │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_758792-MLU78898463580_092024-I.jpg │ ARS         │            10 │  821599.0 │        1282499 │                      │           821599.0 │ true                             │ 2024-10-22 00:00:00-03             │ 2024-10-31 23:59:00-03           │ ARS                     │ TMP                             │                    1282499 │ promotion        │ marketplace_campaign                 │ OFFER-MLA1914171672-10197892875    │                150 │             96166 │ ESPACIO ELECTRONICA │ true             │ true                │ false                   │ true                    │ cross_docking           │ me2            │                       -1 │ 2044-09-15 01:00:00-03     │   31875925 │ ESPACIO ELECTRONICA  │                      6 │            136933.17 │                  0 │ ARS                       │ false                                         │ false                                            │ true            │ NULL         │ 1730421501.3225703 │ 4U0Em/DzWAaMAA │ coupon                             │                                      25400 │ cm_med_uplift_P-MLA14287012         │ P-MLA14287012                     │                                 846999 │ 54584                           │                                              35.94 │ 2024-10-31 23:59:00-03                  │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                         NULL │
# │       ·       │                         ·                                                                                                │  ·        │              ·               │      ·             │    ·            │                         ·                                                                                                │                                                     ·                                                                                                                                                │     ·       │  ·      │    ·        │       ·       │                               ·                                │  ·          │             · │      ·    │             ·  │          ·           │               ·    │  ·                               │  ·                                 │  ·                               │  ·                      │  ·                              │                         ·  │    ·             │  ·                                   │  ·                                 │                  · │                ·  │  ·                  │  ·               │  ·                  │   ·                     │  ·                      │      ·                  │  ·             │                        · │           ·                │       ·    │      ·               │                      · │                 ·    │                  · │  ·                        │   ·                                           │   ·                                              │  ·              │  ·           │         ·          │       ·        │  ·                                 │                                         ·  │  ·                                  │  ·                                │                                     ·  │  ·                              │                                                 ·  │  ·                                      │                       ·  │                                   ·  │                                               ·  │                                                   ·  │                           ·  │
# │       ·       │                         ·                                                                                                │  ·        │              ·               │      ·             │    ·            │                         ·                                                                                                │                                                     ·                                                                                                                                                │     ·       │  ·      │    ·        │       ·       │                               ·                                │  ·          │             · │      ·    │             ·  │          ·           │               ·    │  ·                               │  ·                                 │  ·                               │  ·                      │  ·                              │                         ·  │    ·             │  ·                                   │  ·                                 │                  · │                ·  │  ·                  │  ·               │  ·                  │   ·                     │  ·                      │      ·                  │  ·             │                        · │           ·                │       ·    │      ·               │                      · │                 ·    │                  · │  ·                        │   ·                                           │   ·                                              │  ·              │  ·           │         ·          │       ·        │  ·                                 │                                         ·  │  ·                                  │  ·                                │                                     ·  │  ·                              │                                                 ·  │  ·                                      │                       ·  │                                   ·  │                                               ·  │                                                   ·  │                           ·  │
# │       ·       │                         ·                                                                                                │  ·        │              ·               │      ·             │    ·            │                         ·                                                                                                │                                                     ·                                                                                                                                                │     ·       │  ·      │    ·        │       ·       │                               ·                                │  ·          │             · │      ·    │             ·  │          ·           │               ·    │  ·                               │  ·                                 │  ·                               │  ·                      │  ·                              │                         ·  │    ·             │  ·                                   │  ·                                 │                  · │                ·  │  ·                  │  ·               │  ·                  │   ·                     │  ·                      │      ·                  │  ·             │                        · │           ·                │       ·    │      ·               │                      · │                 ·    │                  · │  ·                        │   ·                                           │   ·                                              │  ·              │  ·           │         ·          │       ·        │  ·                                 │                                         ·  │  ·                                  │  ·                                │                                     ·  │  ·                              │                                                 ·  │  ·                                      │                       ·  │                                   ·  │                                               ·  │                                                   ·  │                           ·  │
# │ MLA1867596242 │ Notebook Enova 14 Celeron N4020 Ram 4gb Ssd 128gb                                                                        │ new       │ 940069-MLU72582966852_112023 │ MLA23827239        │ gold_special    │ notebook-enova-14-celeron-n4020-ram-4gb-ssd-128gb                                                                        │ https://articulo.mercadolibre.com.ar/MLA-1867596242-notebook-enova-14-celeron-n4020-ram-4gb-ssd-128gb-_JM                                                                                            │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_940069-MLU72582966852_112023-I.jpg │ ARS         │            41 │  357999.0 │           NULL │                      │           357999.0 │ true                             │ NULL                               │ NULL                             │ ARS                     │ TMP                             │                       NULL │ standard         │ NULL                                 │ NULL                               │                  1 │              NULL │ NULL                │ true             │ true                │ false                   │ true                    │ xd_drop_off             │ me2            │                       -1 │ 2044-07-26 01:00:00-03     │  144865421 │ TREMOR HOGAR         │                      6 │             69260.87 │               NULL │ ARS                       │ false                                         │ false                                            │ false           │ NULL         │ 1730421812.1861982 │ M31VlWmm/PK99A │ NULL                               │                                       NULL │ NULL                                │ NULL                              │                                   NULL │ NULL                            │                                               NULL │ NULL                                    │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                        16.08 │
# │ MLA1777602088 │ Notebook Acer Aspire 5 Intel Core I5 8gb Ram 256gb Windows                                                               │ new       │ 674425-MLA51199390292_082022 │ MLA21270524        │ gold_pro        │ notebook-acer-aspire-5-intel-core-i5-8gb-ram-256gb-windows                                                               │ https://www.mercadolibre.com.ar/notebook-acer-aspire-5-intel-core-i5-8gb-ram-256gb-windows/p/MLA21270524#wid=MLA1777602088&sid=unknown                                                               │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_674425-MLA51199390292_082022-I.jpg │ ARS         │            42 │ 1206499.0 │           NULL │                      │          1206499.0 │ true                             │ NULL                               │ NULL                             │ ARS                     │ TMP                             │                       NULL │ standard         │ NULL                                 │ NULL                               │                  1 │              NULL │ NULL                │ true             │ true                │ false                   │ true                    │ cross_docking           │ me2            │                       -1 │ 2044-05-12 01:00:00-03     │   19009036 │ JFCELECTRONICA       │                      9 │            134055.44 │                  0 │ ARS                       │ false                                         │ false                                            │ true            │ NULL         │ 1730421812.1861982 │ 5W/2VrUooW59xg │ NULL                               │                                       NULL │ NULL                                │ NULL                              │                                   NULL │ NULL                            │                                               NULL │ NULL                                    │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                         NULL │
# │ MLA1451535401 │ Notebook Asus Vivobook 16 X1605 Core I7 24gb 1tb Ssd                                                                     │ new       │ 892019-MLA79218098832_092024 │ MLA41172457        │ gold_special    │ notebook-asus-vivobook-16-x1605-core-i7-24gb-1tb-ssd                                                                     │ https://articulo.mercadolibre.com.ar/MLA-1451535401-notebook-asus-vivobook-16-x1605-core-i7-24gb-1tb-ssd-_JM                                                                                         │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_892019-MLA79218098832_092024-I.jpg │ ARS         │            43 │ 1268299.0 │        2122499 │                      │          1268299.0 │ true                             │ 2024-10-22 00:00:00-03             │ 2024-10-31 23:59:00-03           │ ARS                     │ TMP                             │                    2122499 │ promotion        │ marketplace_campaign                 │ OFFER-MLA1451535401-10197892786    │                  1 │             96166 │ ESPACIO ELECTRONICA │ true             │ true                │ false                   │ true                    │ cross_docking           │ me2            │                       -1 │ 2044-09-17 01:00:00-03     │   31875925 │ ESPACIO ELECTRONICA  │                      6 │            293801.46 │               NULL │ ARS                       │ false                                         │ false                                            │ false           │ NULL         │ 1730421812.1861982 │ +2qN9Vo3YzuRQg │ coupon                             │                                      66700 │ cm_med_uplift_P-MLA14287012         │ P-MLA14287012                     │                                1334999 │ 54584                           │                                              40.25 │ 2024-10-31 23:59:00-03                  │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                        38.99 │
# │ MLA1835292016 │ Notebook Hp 14-ep1002la Core Ultra 5 8gb Ram 512gb Pcie W11                                                              │ new       │ 616524-MLA78383958443_082024 │ MLA39395073        │ gold_special    │ notebook-hp-14-ep1002la-core-ultra-5-8gb-ram-512gb-pcie-w11                                                              │ https://articulo.mercadolibre.com.ar/MLA-1835292016-notebook-hp-14-ep1002la-core-ultra-5-8gb-ram-512gb-pcie-w11-_JM                                                                                  │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_616524-MLA78383958443_082024-I.jpg │ ARS         │            44 │ 1609999.0 │           NULL │                      │          1609999.0 │ true                             │ NULL                               │ NULL                             │ ARS                     │ TMP                             │                       NULL │ standard         │ NULL                                 │ NULL                               │                250 │               317 │ HP Tienda Oficial   │ true             │ true                │ false                   │ true                    │ cross_docking           │ me2            │                       -1 │ 2044-09-05 16:31:19.589-03 │  260474743 │ TIENDAOFICIALHP-DM   │                      6 │            372956.27 │               NULL │ ARS                       │ false                                         │ false                                            │ false           │ NULL         │ 1730421812.1861982 │ j6SOVCKUIh0nyw │ NULL                               │                                       NULL │ NULL                                │ NULL                              │                                   NULL │ NULL                            │                                               NULL │ NULL                                    │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                        38.99 │
# │ MLA910702116  │ Notebook Bangho Intel Core I7 15,6 Hd 32gb 480gb Ssd Gamer                                                               │ new       │ 664667-MLA45402550765_032021 │ MLA17328361        │ gold_special    │ notebook-bangho-intel-core-i7-156-hd-32gb-480gb-ssd-gamer                                                                │ https://articulo.mercadolibre.com.ar/MLA-910702116-notebook-bangho-intel-core-i7-156-hd-32gb-480gb-ssd-gamer-_JM                                                                                     │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_664667-MLA45402550765_032021-I.jpg │ ARS         │            45 │ 1012799.0 │        1463399 │                      │          1012799.0 │ true                             │ 2024-10-22 00:00:00-03             │ 2024-10-31 23:59:00-03           │ ARS                     │ TMP                             │                    1463399 │ promotion        │ marketplace_campaign                 │ OFFER-MLA910702116-10197727336     │                  1 │             96166 │ ESPACIO ELECTRONICA │ true             │ true                │ false                   │ true                    │ cross_docking           │ me2            │                       -1 │ 2041-02-28 01:00:00-03     │   31875925 │ ESPACIO ELECTRONICA  │                      6 │            234614.89 │               NULL │ ARS                       │ false                                         │ false                                            │ false           │ NULL         │ 1730421812.1861982 │ rTpLdvJudSx82w │ coupon                             │                                      53200 │ cm_med_uplift_P-MLA14287012         │ P-MLA14287012                     │                                1065999 │ 54584                           │                                              30.79 │ 2024-10-31 23:59:00-03                  │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                        38.99 │
# ...
# │ MLA1929850450 │ Notebook Lenovo 20tbs8sn00 1tb Ssd Tp E14 I7 40gb 1tb W11pro                                                             │ new       │ 653119-MLA79558119034_102024 │ MLA33719044        │ gold_special    │ notebook-lenovo-20tbs8sn00-1tb-ssd-tp-e14-i7-40gb-1tb-w11pro                                                             │ https://articulo.mercadolibre.com.ar/MLA-1929850450-notebook-lenovo-20tbs8sn00-1tb-ssd-tp-e14-i7-40gb-1tb-w11pro-_JM                                                                                 │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_653119-MLA79558119034_102024-I.jpg │ ARS         │            47 │ 1422767.0 │        1716762 │                      │          1422767.0 │ true                             │ 2024-10-29 00:15:00-03             │ 2024-10-31 23:59:00-03           │ ARS                     │ TMP                             │                    1716762 │ promotion        │ marketplace_campaign                 │ OFFER-MLA1929850450-10200937970    │                  1 │              NULL │ NULL                │ true             │ true                │ false                   │ true                    │ cross_docking           │ me2            │                       -1 │ 2044-10-02 01:00:00-03     │   68286146 │ INSUMOS_ACUARIO      │                      6 │            329583.98 │               NULL │ ARS                       │ false                                         │ false                                            │ false           │ NULL         │ 1730421812.1861982 │ kkpSd9dBQKfaiA │ coupon                             │                                      36481 │ cm_med_uplift_P-MLA14287012         │ P-MLA14287012                     │                                1459248 │ 54584                           │                                              17.12 │ 2024-10-31 23:59:00-03                  │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                        38.99 │
# │ MLA1920185466 │ Notebook Dell Latitude E7470 - Core I5 - 240gb - 8gb Ram                                                                 │ new       │ 668053-MLA79596677957_092024 │ MLA26792543        │ gold_special    │ notebook-dell-latitude-e7470-core-i5-240gb-8gb-ram                                                                       │ https://articulo.mercadolibre.com.ar/MLA-1920185466-notebook-dell-latitude-e7470-core-i5-240gb-8gb-ram-_JM                                                                                           │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_668053-MLA79596677957_092024-I.jpg │ ARS         │            48 │ 477106.15 │         545000 │                      │          477106.15 │ true                             │ 2024-10-01 00:50:19-03             │ 2024-10-31 23:50:00-03           │ ARS                     │ TMP                             │                     545000 │ promotion        │ marketplace_campaign                 │ OFFER-MLA1920185466-10201091616    │                  1 │             94962 │ GREENCOMPUTER       │ true             │ true                │ false                   │ true                    │ xd_drop_off             │ me2            │                       -1 │ 2044-09-21 01:00:00-03     │  455063291 │ GREENCOMPUTER        │                      6 │            110521.64 │               NULL │ ARS                       │ false                                         │ false                                            │ false           │ NULL         │ 1730421812.1861982 │ qbviNrnEaqYLHg │ coupon                             │                                       NULL │ cm_med_uplift_P-MLA14293054         │ P-MLA14293054                     │                                   NULL │ 54852                           │                                              12.46 │ 2024-10-31 23:50:00-03                  │                     NULL │                                 NULL │                                        491261.42 │                                             14155.27 │                        38.99 │
# │ MLA1443339083 │ Notebook Hp 240 G9 14 Intel Celeron N4500 16gb 512gb Ssd Csi                                                             │ new       │ 769406-MLA78177851988_082024 │ MLA39454777        │ gold_pro        │ notebook-hp-240-g9-14-intel-celeron-n4500-16gb-512gb-ssd-csi                                                             │ https://articulo.mercadolibre.com.ar/MLA-1443339083-notebook-hp-240-g9-14-intel-celeron-n4500-16gb-512gb-ssd-csi-_JM                                                                                 │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_769406-MLA78177851988_082024-I.jpg │ ARS         │            49 │  688999.0 │        1024499 │                      │           688999.0 │ true                             │ 2024-10-24 00:00:00-03             │ 2024-10-31 23:59:00-03           │ ARS                     │ TMP                             │                    1024499 │ promotion        │ marketplace_campaign                 │ OFFER-MLA1443339083-10198939294    │                  1 │             96166 │ ESPACIO ELECTRONICA │ true             │ true                │ false                   │ true                    │ cross_docking           │ me2            │                       -1 │ 2044-08-09 01:00:00-03     │   31875925 │ ESPACIO ELECTRONICA  │                      3 │            229666.33 │                  0 │ ARS                       │ false                                         │ false                                            │ false           │ NULL         │ 1730421812.1861982 │ 4d3MzNqjpgfF0Q │ coupon                             │                                      14000 │ cm_med_uplift_P-MLA14287012         │ P-MLA14287012                     │                                 702999 │ 54584                           │                                              32.75 │ 2024-10-31 23:59:00-03                  │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                         NULL │
# │ MLA1393716371 │ Notebook Lenovo I7-1165g7 12gb 512 Gb Ssd 15,6  Wh11                                                                     │ new       │ 667632-MLA72468291482_102023 │ MLA17914427        │ gold_special    │ notebook-lenovo-i7-1165g7-12gb-512-gb-ssd-156-wh11                                                                       │ https://articulo.mercadolibre.com.ar/MLA-1393716371-notebook-lenovo-i7-1165g7-12gb-512-gb-ssd-156-wh11-_JM                                                                                           │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_667632-MLA72468291482_102023-I.jpg │ ARS         │            50 │ 1260000.0 │           NULL │                      │          1260000.0 │ true                             │ NULL                               │ NULL                             │ ARS                     │ TMP                             │                       NULL │ standard         │ NULL                                 │ NULL                               │                  1 │             97394 │ Importbernal        │ true             │ true                │ false                   │ true                    │ xd_drop_off             │ me2            │                       -1 │ 2044-08-09 17:43:46-03     │  656691895 │ INVERSIONES BERNAL   │                      6 │             291879.0 │               NULL │ ARS                       │ false                                         │ false                                            │ false           │ NULL         │ 1730421812.1861982 │ 4m104ZfYjFKR5Q │ NULL                               │                                       NULL │ NULL                                │ NULL                              │                                   NULL │ NULL                            │                                               NULL │ NULL                                    │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                        38.99 │
# ├───────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────┴──────────────────────────────┴────────────────────┴─────────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴─────────────┴─────────┴─────────────┴───────────────┴────────────────────────────────────────────────────────────────┴─────────────┴───────────────┴───────────┴────────────────┴──────────────────────┴────────────────────┴──────────────────────────────────┴────────────────────────────────────┴──────────────────────────────────┴─────────────────────────┴─────────────────────────────────┴────────────────────────────┴──────────────────┴──────────────────────────────────────┴────────────────────────────────────┴────────────────────┴───────────────────┴─────────────────────┴──────────────────┴─────────────────────┴─────────────────────────┴─────────────────────────┴─────────────────────────┴────────────────┴──────────────────────────┴────────────────────────────┴────────────┴──────────────────────┴────────────────────────┴──────────────────────┴────────────────────┴───────────────────────────┴───────────────────────────────────────────────┴──────────────────────────────────────────────────┴─────────────────┴──────────────┴────────────────────┴────────────────┴────────────────────────────────────┴────────────────────────────────────────────┴─────────────────────────────────────┴───────────────────────────────────┴────────────────────────────────────────┴─────────────────────────────────┴────────────────────────────────────────────────────┴─────────────────────────────────────────┴──────────────────────────┴──────────────────────────────────────┴──────────────────────────────────────────────────┴──────────────────────────────────────────────────────┴──────────────────────────────┤
# │ 1098 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              64 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Esta tabla contiene los contenidos de las publicaciones. Va a ser nuestra tabla "raw" principal

# %%
base.sql('''
SELECT *
FROM laptop.search__attributes                                               
''')
# Out:
# ┌────────────────────┬──────────────────────────────┬──────────┬───────────────┬────────────────────┬──────────────────────┬──────────────────┬─────────────┬────────────────┬───────────────┬────────────────┬──────────────────────┬────────────────────┬────────────────────────────────┐
# │         id         │             name             │ value_id │  value_name   │ attribute_group_id │ attribute_group_name │      source      │ value_type  │ _dlt_parent_id │ _dlt_list_idx │    _dlt_id     │ value_struct__number │ value_struct__unit │ value_struct__number__v_double │
# │      varchar       │           varchar            │ varchar  │    varchar    │      varchar       │       varchar        │      int64       │   varchar   │    varchar     │     int64     │    varchar     │        int64         │      varchar       │             double             │
# ├────────────────────┼──────────────────────────────┼──────────┼───────────────┼────────────────────┼──────────────────────┼──────────────────┼─────────────┼────────────────┼───────────────┼────────────────┼──────────────────────┼────────────────────┼────────────────────────────────┤
# │ BRAND              │ Marca                        │ 27222    │ EXO           │ OTHERS             │ Otros                │                1 │ string      │ GCY1SBkSzYYtlA │             0 │ y2aFiuP69UZ3jA │                 NULL │ NULL               │                           NULL │
# │ COLOR              │ Color                        │ 283165   │ Gris          │ OTHERS             │ Otros                │                1 │ string      │ GCY1SBkSzYYtlA │             1 │ qjrcSESk/xdr5w │                 NULL │ NULL               │                           NULL │
# │ GTIN               │ Código universal de producto │ NULL     │ 7797678020029 │ OTHERS             │ Otros                │ 6402814585011704 │ string      │ GCY1SBkSzYYtlA │             2 │ HRrO4NUv0vK2/w │                 NULL │ NULL               │                           NULL │
# │ ITEM_CONDITION     │ Condición del ítem           │ 2230284  │ Nuevo         │ OTHERS             │ Otros                │ 6402814585011704 │ list        │ GCY1SBkSzYYtlA │             3 │ dKjEvN2HBdUfYQ │                 NULL │ NULL               │                           NULL │
# │ LINE               │ Línea                        │ 196      │ Smart         │ OTHERS             │ Otros                │                1 │ string      │ GCY1SBkSzYYtlA │             4 │ RDRklszngfSi2Q │                 NULL │ NULL               │                           NULL │
# │ MAIN_COLOR         │ Color principal              │ 2450294  │ Gris          │ OTHERS             │ Otros                │                1 │ list        │ GCY1SBkSzYYtlA │             5 │ UE7WOuLLyOpSog │                 NULL │ NULL               │                           NULL │
# │ MODEL              │ Modelo                       │ 11385239 │ T38           │ OTHERS             │ Otros                │                1 │ string      │ GCY1SBkSzYYtlA │             6 │ YBOmvBkk3a/uCA │                 NULL │ NULL               │                           NULL │
# │ PROCESSOR_BRAND    │ Marca del procesador         │ 7855833  │ Intel         │ OTHERS             │ Otros                │                1 │ list        │ GCY1SBkSzYYtlA │             7 │ CRZQkLLLdR4aAg │                 NULL │ NULL               │                           NULL │
# │ PROCESSOR_LINE     │ Línea del procesador         │ 44273    │ Celeron       │ OTHERS             │ Otros                │                1 │ string      │ GCY1SBkSzYYtlA │             8 │ uPpj5dYuBEuzCw │                 NULL │ NULL               │                           NULL │
# │ PROCESSOR_MODEL    │ Modelo del procesador        │ 9233933  │ N4020         │ OTHERS             │ Otros                │                1 │ string      │ GCY1SBkSzYYtlA │             9 │ cCF7MYoKIhiHUg │                 NULL │ NULL               │                           NULL │
# │   ·                │   ·                          │  ·       │   ·           │   ·                │   ·                  │                · │   ·         │       ·        │             · │       ·        │                   ·  │  ·                 │                             ·  │
# │   ·                │   ·                          │  ·       │   ·           │   ·                │   ·                  │                · │   ·         │       ·        │             · │       ·        │                   ·  │  ·                 │                             ·  │
# │   ·                │   ·                          │  ·       │   ·           │   ·                │   ·                  │                · │   ·         │       ·        │             · │       ·        │                   ·  │  ·                 │                             ·  │
# │ BRAND              │ Marca                        │ 7494     │ Lenovo        │ OTHERS             │ Otros                │                1 │ string      │ 5SY4owxJu1t4KA │             1 │ 58NNcHh9/IDC+Q │                 NULL │ NULL               │                           NULL │
# │ ITEM_CONDITION     │ Condición del ítem           │ 2230284  │ Nuevo         │ OTHERS             │ Otros                │ 6402814585011704 │ list        │ 5SY4owxJu1t4KA │             2 │ lSvNdqQoBj3Eug │                 NULL │ NULL               │                           NULL │
# │ LINE               │ Línea                        │ 22153848 │ LOQ           │ OTHERS             │ Otros                │                1 │ string      │ 5SY4owxJu1t4KA │             3 │ NAKLVEB+Ncq0Wg │                 NULL │ NULL               │                           NULL │
# │ MODEL              │ Modelo                       │ 43168110 │ LOQ 15IAX8    │ OTHERS             │ Otros                │                1 │ string      │ 5SY4owxJu1t4KA │             4 │ T0WWF67e39e8OQ │                 NULL │ NULL               │                           NULL │
# │ PROCESSOR_BRAND    │ Marca del procesador         │ 7855833  │ Intel         │ OTHERS             │ Otros                │                1 │ list        │ 5SY4owxJu1t4KA │             5 │ oYr+VUPiMkpXuQ │                 NULL │ NULL               │                           NULL │
# │ PROCESSOR_LINE     │ Línea del procesador         │ 7769178  │ Core i5       │ OTHERS             │ Otros                │                1 │ string      │ 5SY4owxJu1t4KA │             6 │ bCBxODAMjj6VAQ │                 NULL │ NULL               │                           NULL │
# │ PROCESSOR_MODEL    │ Modelo del procesador        │ 39093605 │ 12450HX       │ OTHERS             │ Otros                │                1 │ string      │ 5SY4owxJu1t4KA │             7 │ Z1gwqVqmnJrmnw │                 NULL │ NULL               │                           NULL │
# │ WEIGHT             │ Peso                         │ NULL     │ 2.38 kg       │ OTHERS             │ Otros                │                1 │ number_unit │ 5SY4owxJu1t4KA │             8 │ q674nYgicN3xhg │                 NULL │ kg                 │                           2.38 │
# │ ALPHANUMERIC_MODEL │ Modelo alfanumérico          │ -1       │ NULL          │ OTHERS             │ Otros                │ 6402814585011704 │ string      │ Cp0X6znkiaq0vA │             0 │ iGKoMPi4mQG89Q │                 NULL │ NULL               │                           NULL │
# │ BRAND              │ Marca                        │ 27222    │ EXO           │ OTHERS             │ Otros                │ 6402814585011704 │ string      │ Cp0X6znkiaq0vA │             1 │ h6PqR/dpqvCXZg │                 NULL │ NULL               │                           NULL │
# ├────────────────────┴──────────────────────────────┴──────────┴───────────────┴────────────────────┴──────────────────────┴──────────────────┴─────────────┴────────────────┴───────────────┴────────────────┴──────────────────────┴────────────────────┴────────────────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                                                                                 14 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Esta tabla contiene Información sobre los atributos de los productos. La vamos a utilizar

# %%
base.sql('''
SELECT *
FROM laptop.search__attributes__values                                             
''')
# Out:
# ┌──────────┬───────────────┬──────────────────┬────────────────┬───────────────┬────────────────┬────────────────┬──────────────┬──────────────────────────┐
# │    id    │     name      │      source      │ _dlt_parent_id │ _dlt_list_idx │    _dlt_id     │ struct__number │ struct__unit │ struct__number__v_double │
# │ varchar  │    varchar    │      int64       │    varchar     │     int64     │    varchar     │     int64      │   varchar    │          double          │
# ├──────────┼───────────────┼──────────────────┼────────────────┼───────────────┼────────────────┼────────────────┼──────────────┼──────────────────────────┤
# │ 27222    │ EXO           │                1 │ y2aFiuP69UZ3jA │             0 │ FAkcqiQvWGCjkg │           NULL │ NULL         │                     NULL │
# │ 283165   │ Gris          │                1 │ qjrcSESk/xdr5w │             0 │ si5WvA857BO6tw │           NULL │ NULL         │                     NULL │
# │ NULL     │ 7797678020029 │  385122562515662 │ HRrO4NUv0vK2/w │             0 │ 9ZfqNzz3JURtUQ │           NULL │ NULL         │                     NULL │
# │ 2230284  │ Nuevo         │ 6402814585011704 │ dKjEvN2HBdUfYQ │             0 │ CD51mWuKYCSEYg │           NULL │ NULL         │                     NULL │
# │ 196      │ Smart         │                1 │ RDRklszngfSi2Q │             0 │ 7uO30UyNlUj7lA │           NULL │ NULL         │                     NULL │
# │ 2450294  │ Gris          │                1 │ UE7WOuLLyOpSog │             0 │ pkYUP3PnMjs3PQ │           NULL │ NULL         │                     NULL │
# │ 11385239 │ T38           │                1 │ YBOmvBkk3a/uCA │             0 │ G7aS8lRIZnd98g │           NULL │ NULL         │                     NULL │
# │ 7855833  │ Intel         │                1 │ CRZQkLLLdR4aAg │             0 │ RMxKTR9g2xtdwg │           NULL │ NULL         │                     NULL │
# │ 44273    │ Celeron       │                1 │ uPpj5dYuBEuzCw │             0 │ /oBunBTD5wlBlQ │           NULL │ NULL         │                     NULL │
# │ 9233933  │ N4020         │                1 │ cCF7MYoKIhiHUg │             0 │ m3dLNEw41y9JVw │           NULL │ NULL         │                     NULL │
# │    ·     │   ·           │                · │       ·        │             · │       ·        │             ·  │  ·           │                       ·  │
# │    ·     │   ·           │                · │       ·        │             · │       ·        │             ·  │  ·           │                       ·  │
# │    ·     │   ·           │                · │       ·        │             · │       ·        │             ·  │  ·           │                       ·  │
# │ 7769178  │ Core i5       │                1 │ GtMkiX8FIixQxQ │             0 │ dmVLCI/ktnDh1A │           NULL │ NULL         │                     NULL │
# │ 9868407  │ 1135G7        │                1 │ VGlrW73ExJgtgg │             0 │ orYfxQAHeeBOnQ │           NULL │ NULL         │                     NULL │
# │ 7900376  │ 1.74 kg       │                1 │ 3fIHEGohKcsHLg │             0 │ 6R20rHu+prmudQ │           NULL │ kg           │                     1.74 │
# │ 42706603 │ 83GS00EBAR    │                1 │ gbDGHjBlHbiMqg │             0 │ ENokLZitwQ+k8g │           NULL │ NULL         │                     NULL │
# │ 7494     │ Lenovo        │                1 │ 58NNcHh9/IDC+Q │             0 │ ykiv/MRqJMx4Xg │           NULL │ NULL         │                     NULL │
# │ 2230284  │ Nuevo         │ 6402814585011704 │ lSvNdqQoBj3Eug │             0 │ TqNHj2bm8tC+Mw │           NULL │ NULL         │                     NULL │
# │ 22153848 │ LOQ           │                1 │ NAKLVEB+Ncq0Wg │             0 │ snZeE4RqITub4A │           NULL │ NULL         │                     NULL │
# │ 43168110 │ LOQ 15IAX8    │                1 │ T0WWF67e39e8OQ │             0 │ Mzrs3iEFLLnUOQ │           NULL │ NULL         │                     NULL │
# │ 7855833  │ Intel         │                1 │ oYr+VUPiMkpXuQ │             0 │ wU3roeBc8b6seg │           NULL │ NULL         │                     NULL │
# │ 7769178  │ Core i5       │                1 │ bCBxODAMjj6VAQ │             0 │ pEULyvXVuZdAtA │           NULL │ NULL         │                     NULL │
# ├──────────┴───────────────┴──────────────────┴────────────────┴───────────────┴────────────────┴────────────────┴──────────────┴──────────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                  9 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Esta tabla contiene información redundante, no la vamos a utilizar

# %%
base.sql('''
SELECT *
FROM laptop.search__sale_price__conditions__context_restrictions                                             
''')
# Out:
# ┌─────────────────────┬────────────────┬───────────────┬────────────────┐
# │        value        │ _dlt_parent_id │ _dlt_list_idx │    _dlt_id     │
# │       varchar       │    varchar     │     int64     │    varchar     │
# ├─────────────────────┼────────────────┼───────────────┼────────────────┤
# │ channel_marketplace │ GCY1SBkSzYYtlA │             0 │ TNGSzS9yWP+I4g │
# │ channel_marketplace │ nZOsXziZMoAYDA │             0 │ SpiM5dkzCUb93w │
# │ channel_marketplace │ jSo+pMlakVKXiQ │             0 │ 7LMerbTXUN+knw │
# │ channel_marketplace │ 5TRAVuk7+KTsLQ │             0 │ 0JCJDjK5Qj6/jA │
# │ channel_marketplace │ Qi1t+JCrYETfsQ │             0 │ 1GrCILA8ueyLdQ │
# │ channel_marketplace │ UkUV61jkYLl8bQ │             0 │ 8E1WKxvozqGTeQ │
# │ channel_marketplace │ LECj9DmSQTRTfQ │             0 │ Aaj+UVwDQJSCdg │
# │ channel_marketplace │ KZdY/mahSG38VQ │             0 │ YH6vJ0BjrYb6qQ │
# │ channel_marketplace │ sqiQ1Nd1YF7HgA │             0 │ Fwrrs6EakfoIIQ │
# │ channel_marketplace │ 4U0Em/DzWAaMAA │             0 │ O/0skM/ixtKJYA │
# │          ·          │       ·        │             · │       ·        │
# │          ·          │       ·        │             · │       ·        │
# │          ·          │       ·        │             · │       ·        │
# │ channel_marketplace │ xVvBCaJLXCa/OQ │             0 │ 3bmXrlokQeLbLQ │
# │ channel_marketplace │ q6k3Mla4RshWEA │             0 │ WTPawSCGG28GNQ │
# │ channel_marketplace │ clFpp9pm9oRmkg │             0 │ 1y8qmN+EMbN9bA │
# │ channel_marketplace │ ioiHLjjv3g/sVA │             0 │ R8Zbt76rw8WA5w │
# │ channel_marketplace │ +2qN9Vo3YzuRQg │             0 │ VBusRDK1Jh5fxA │
# │ channel_marketplace │ rTpLdvJudSx82w │             0 │ wIJHgJwRhBCLBw │
# │ channel_marketplace │ 7PaCEkiyZ6nfgA │             0 │ NfCfXmS1P2Tocg │
# │ channel_marketplace │ kkpSd9dBQKfaiA │             0 │ 85Fu1o1EDSzTgg │
# │ channel_marketplace │ qbviNrnEaqYLHg │             0 │ jRdcaiJZCVxvEA │
# │ channel_marketplace │ 4d3MzNqjpgfF0Q │             0 │ Jbt5mpvbyZ4cjg │
# ├─────────────────────┴────────────────┴───────────────┴────────────────┤
# │ 834 rows (20 shown)                                         4 columns │
# └───────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Esta tabla tiene información que no es útil

# %%
base.sql('''
SELECT *
FROM laptop.search__shipping__tags                                             
''')
# Out:
# ┌─────────────────────────┬────────────────┬───────────────┬────────────────┐
# │          value          │ _dlt_parent_id │ _dlt_list_idx │    _dlt_id     │
# │         varchar         │    varchar     │     int64     │    varchar     │
# ├─────────────────────────┼────────────────┼───────────────┼────────────────┤
# │ mandatory_free_shipping │ GCY1SBkSzYYtlA │             0 │ TLy7mhrSUsoYiA │
# │ self_service_in         │ nZOsXziZMoAYDA │             0 │ HS3FRBeeb5sKpg │
# │ mandatory_free_shipping │ nZOsXziZMoAYDA │             1 │ r2at+ejt2fnkTQ │
# │ self_service_in         │ jSo+pMlakVKXiQ │             0 │ DR0dDp2OsPIOxQ │
# │ mandatory_free_shipping │ jSo+pMlakVKXiQ │             1 │ Ths2gupu3KaqiA │
# │ self_service_in         │ 5TRAVuk7+KTsLQ │             0 │ w4UVtGCakihqLg │
# │ mandatory_free_shipping │ 5TRAVuk7+KTsLQ │             1 │ NwYxEde+/+OmFw │
# │ fulfillment             │ Qi1t+JCrYETfsQ │             0 │ MRvvcgIl6xpo0g │
# │ self_service_in         │ Qi1t+JCrYETfsQ │             1 │ BCtIlUnVH42RCA │
# │ mandatory_free_shipping │ Qi1t+JCrYETfsQ │             2 │ AWO6S9Omja2Bkg │
# │            ·            │       ·        │             · │       ·        │
# │            ·            │       ·        │             · │       ·        │
# │            ·            │       ·        │             · │       ·        │
# │ mandatory_free_shipping │ rTpLdvJudSx82w │             1 │ zznSgotvgMaumw │
# │ mandatory_free_shipping │ 7PaCEkiyZ6nfgA │             0 │ jJkXY+YT36qJPw │
# │ self_service_in         │ kkpSd9dBQKfaiA │             0 │ 9GEKwF3fB4s0KQ │
# │ mandatory_free_shipping │ kkpSd9dBQKfaiA │             1 │ XhHj70DKirIdiA │
# │ self_service_in         │ qbviNrnEaqYLHg │             0 │ 68CDGvdv3X1cJA │
# │ mandatory_free_shipping │ qbviNrnEaqYLHg │             1 │ o/vpbqoDrib7hg │
# │ self_service_in         │ 4d3MzNqjpgfF0Q │             0 │ Cvr9wEaWk1v7Hw │
# │ mandatory_free_shipping │ 4d3MzNqjpgfF0Q │             1 │ N1Bv8UDZuwW8WA │
# │ self_service_in         │ 4m104ZfYjFKR5Q │             0 │ 8VEaYcqtl3iR4Q │
# │ mandatory_free_shipping │ 4m104ZfYjFKR5Q │             1 │ cu+Rzbhbh4rH8A │
# ├─────────────────────────┴────────────────┴───────────────┴────────────────┤
# │ 2128 rows (20 shown)                                            4 columns │
# └───────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Esta tabla tiene Información sobre envíos que no es necesaria. No la vamos a utilizar

# %%
base.sql('''
SELECT *
FROM laptop.seller                                             
''')
# Out:
# ┌────────────┬────────────────────────────┬────────────┬──────────────────┬────────────────┬───────────┬─────────┬──────────────────────────────────────────────────────────────┬─────────────────────────────┬────────────────────────────────────────┬─────────────────────────────────────────┬────────────────────────────────────────┬─────────────────────┬────────────────────┬────────────────┐
# │     id     │          nickname          │ country_id │  address__city   │ address__state │ user_type │ site_id │                          permalink                           │ seller_reputation__level_id │ seller_reputation__power_seller_status │ seller_reputation__transactions__period │ seller_reputation__transactions__total │ status__site_status │    _dlt_load_id    │    _dlt_id     │
# │   int64    │          varchar           │  varchar   │     varchar      │    varchar     │  varchar  │ varchar │                           varchar                            │           varchar           │                varchar                 │                 varchar                 │                 int64                  │       varchar       │      varchar       │    varchar     │
# ├────────────┼────────────────────────────┼────────────┼──────────────────┼────────────────┼───────────┼─────────┼──────────────────────────────────────────────────────────────┼─────────────────────────────┼────────────────────────────────────────┼─────────────────────────────────────────┼────────────────────────────────────────┼─────────────────────┼────────────────────┼────────────────┤
# │  180214913 │ EXO SA                     │ AR         │ Boedo            │ AR-C           │ brand     │ MLA     │ http://perfil.mercadolibre.com.ar/EXO+SA                     │ 5_green                     │ platinum                               │ historic                                │                                  11878 │ active              │ 1730421501.3225703 │ 49hFFJ3EQLxaoA │
# │   82916233 │ MEXX GAMERS.POR.NATURALEZA │ AR         │ Caballito        │ AR-C           │ brand     │ MLA     │ http://perfil.mercadolibre.com.ar/MEXX+GAMERS.POR.NATURALEZA │ 5_green                     │ platinum                               │ historic                                │                                  54374 │ active              │ 1730421501.3225703 │ 5Bc34IWr4FE0sA │
# │  638528199 │ MULTI.HOGAR                │ AR         │ Villa Crespo     │ AR-C           │ normal    │ MLA     │ http://perfil.mercadolibre.com.ar/MULTI.HOGAR                │ 5_green                     │ platinum                               │ historic                                │                                  21162 │ active              │ 1730421501.3225703 │ Gpt5HF0Dy8g4xw │
# │  187140437 │ HTVS.                      │ AR         │ Junín            │ AR-B           │ normal    │ MLA     │ http://perfil.mercadolibre.com.ar/HTVS.                      │ 5_green                     │ platinum                               │ historic                                │                                  72911 │ active              │ 1730421501.3225703 │ i805kaje/dSdVg │
# │   31875925 │ ESPACIO ELECTRONICA        │ AR         │ Villa Urquiza    │ AR-C           │ brand     │ MLA     │ http://perfil.mercadolibre.com.ar/ESPACIO+ELECTRONICA        │ 5_green                     │ platinum                               │ historic                                │                                  54811 │ active              │ 1730421501.3225703 │ Eta4ZhYUF9tDCA │
# │   31875925 │ ESPACIO ELECTRONICA        │ AR         │ Villa Urquiza    │ AR-C           │ brand     │ MLA     │ http://perfil.mercadolibre.com.ar/ESPACIO+ELECTRONICA        │ 5_green                     │ platinum                               │ historic                                │                                  54811 │ active              │ 1730421501.3225703 │ 0iEbx7amPRodgQ │
# │  256324891 │ PILISAR 33709180849        │ AR         │ Monte Chingolo   │ AR-B           │ brand     │ MLA     │ http://perfil.mercadolibre.com.ar/PILISAR+33709180849        │ 5_green                     │ NULL                                   │ historic                                │                                 201195 │ active              │ 1730421501.3225703 │ DiXnL0C77SpkPg │
# │  131648529 │ PCCENTERCOMPUTERS          │ AR         │ Villa Crespo     │ AR-C           │ normal    │ MLA     │ http://perfil.mercadolibre.com.ar/PCCENTERCOMPUTERS          │ 5_green                     │ platinum                               │ historic                                │                                  27829 │ active              │ 1730421501.3225703 │ 5WYOSByWx+YOGg │
# │  318494504 │ ELECTRO-WORLD GROUP        │ AR         │ Parque Chas      │ AR-C           │ normal    │ MLA     │ http://perfil.mercadolibre.com.ar/ELECTRO-WORLD+GROUP        │ 5_green                     │ platinum                               │ historic                                │                                  67127 │ active              │ 1730421501.3225703 │ yGorm16orpUt1Q │
# │ 1290146649 │ NOTEBOOKSTRADE             │ AR         │ Córdoba          │ AR-X           │ normal    │ MLA     │ http://perfil.mercadolibre.com.ar/NOTEBOOKSTRADE             │ 5_green                     │ silver                                 │ historic                                │                                   1772 │ active              │ 1730421501.3225703 │ 230VVuE7Jd/3DQ │
# │       ·    │    ·                       │ ·          │    ·             │  ·             │   ·       │  ·      │                     ·                                        │    ·                        │   ·                                    │    ·                                    │                                     ·  │   ·                 │         ·          │       ·        │
# │       ·    │    ·                       │ ·          │    ·             │  ·             │   ·       │  ·      │                     ·                                        │    ·                        │   ·                                    │    ·                                    │                                     ·  │   ·                 │         ·          │       ·        │
# │       ·    │    ·                       │ ·          │    ·             │  ·             │   ·       │  ·      │                     ·                                        │    ·                        │   ·                                    │    ·                                    │                                     ·  │   ·                 │         ·          │       ·        │
# │   65156448 │ FEFOTEC                    │ AR         │ San Nicolás      │ AR-C           │ normal    │ MLA     │ http://perfil.mercadolibre.com.ar/FEFOTEC                    │ 5_green                     │ platinum                               │ historic                                │                                   5259 │ active              │ 1730421812.1861982 │ bvfFXWl9a5D7xw │
# │  131648529 │ PCCENTERCOMPUTERS          │ AR         │ Villa Crespo     │ AR-C           │ normal    │ MLA     │ http://perfil.mercadolibre.com.ar/PCCENTERCOMPUTERS          │ 5_green                     │ platinum                               │ historic                                │                                  27829 │ active              │ 1730421812.1861982 │ gJTL4MD92+hLwQ │
# │ 1250965884 │ DIPROSTORE                 │ AR         │ Junín            │ AR-B           │ normal    │ MLA     │ http://perfil.mercadolibre.com.ar/DIPROSTORE                 │ 5_green                     │ platinum                               │ historic                                │                                   7595 │ active              │ 1730421812.1861982 │ 6KXVRmf4fF/0Fw │
# │  131648529 │ PCCENTERCOMPUTERS          │ AR         │ Villa Crespo     │ AR-C           │ normal    │ MLA     │ http://perfil.mercadolibre.com.ar/PCCENTERCOMPUTERS          │ 5_green                     │ platinum                               │ historic                                │                                  27829 │ active              │ 1730421812.1861982 │ nuUiHK7KEEJ+Mw │
# │  187140437 │ HTVS.                      │ AR         │ Junín            │ AR-B           │ normal    │ MLA     │ http://perfil.mercadolibre.com.ar/HTVS.                      │ 5_green                     │ platinum                               │ historic                                │                                  72912 │ active              │ 1730421812.1861982 │ MOCk69aR4ziVuA │
# │   68286146 │ INSUMOS_ACUARIO            │ AR         │ Colegiales       │ AR-C           │ normal    │ MLA     │ http://perfil.mercadolibre.com.ar/INSUMOS_ACUARIO            │ 5_green                     │ platinum                               │ historic                                │                                  62364 │ active              │ 1730421812.1861982 │ GzNVJ7dgpU9YjQ │
# │   31875925 │ ESPACIO ELECTRONICA        │ AR         │ Villa Urquiza    │ AR-C           │ brand     │ MLA     │ http://perfil.mercadolibre.com.ar/ESPACIO+ELECTRONICA        │ 5_green                     │ platinum                               │ historic                                │                                  54814 │ active              │ 1730421812.1861982 │ cilq6ZBMrGrsvQ │
# │  455063291 │ GREENCOMPUTER              │ AR         │ Parque Patricios │ AR-C           │ brand     │ MLA     │ http://perfil.mercadolibre.com.ar/GREENCOMPUTER              │ 5_green                     │ gold                                   │ historic                                │                                   1676 │ active              │ 1730421812.1861982 │ QWD2jhofYqai+g │
# │   31875925 │ ESPACIO ELECTRONICA        │ AR         │ Villa Urquiza    │ AR-C           │ brand     │ MLA     │ http://perfil.mercadolibre.com.ar/ESPACIO+ELECTRONICA        │ 5_green                     │ platinum                               │ historic                                │                                  54814 │ active              │ 1730421812.1861982 │ 2g8zD6Q3Rrs/vA │
# │  656691895 │ INVERSIONES BERNAL         │ AR         │ Bernal           │ AR-B           │ brand     │ MLA     │ http://perfil.mercadolibre.com.ar/INVERSIONES+BERNAL         │ 5_green                     │ platinum                               │ historic                                │                                   9919 │ active              │ 1730421812.1861982 │ pkVZowyXfZ2p3g │
# ├────────────┴────────────────────────────┴────────────┴──────────────────┴────────────────┴───────────┴─────────┴──────────────────────────────────────────────────────────────┴─────────────────────────────┴────────────────────────────────────────┴─────────────────────────────────────────┴────────────────────────────────────────┴─────────────────────┴────────────────────┴────────────────┤
# │ 1098 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                                     15 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Esta tabla contiene información de los vendedores. La vamos a utilizar

# %% [markdown]
# En conclusión, solamente vamos a utilizar las tablas
#
# 1. search
#
# 2. search__attributes
#
# 3. seller

# %% [markdown]
# Corroboramos que esas tablas existan para las otras búsquedas:

# %%
base.sql('''
SELECT DISTINCT table_schema 
FROM information_schema.tables
''')
# Out:
# ┌──────────────┐
# │ table_schema │
# │   varchar    │
# ├──────────────┤
# │ laptop       │
# │ mini_pc      │
# │ pc           │
# └──────────────┘

# %%
base.sql('''
SELECT *
FROM information_schema.tables
WHERE table_name in ('search','search__attributes', 'seller')
''')
# Out:
# ┌───────────────┬──────────────┬────────────────────┬────────────┬──────────────────────────────┬──────────────────────┬───────────────────────────┬──────────────────────────┬────────────────────────┬────────────────────┬──────────┬───────────────┬───────────────┐
# │ table_catalog │ table_schema │     table_name     │ table_type │ self_referencing_column_name │ reference_generation │ user_defined_type_catalog │ user_defined_type_schema │ user_defined_type_name │ is_insertable_into │ is_typed │ commit_action │ TABLE_COMMENT │
# │    varchar    │   varchar    │      varchar       │  varchar   │           varchar            │       varchar        │          varchar          │         varchar          │        varchar         │      varchar       │ varchar  │    varchar    │    varchar    │
# ├───────────────┼──────────────┼────────────────────┼────────────┼──────────────────────────────┼──────────────────────┼───────────────────────────┼──────────────────────────┼────────────────────────┼────────────────────┼──────────┼───────────────┼───────────────┤
# │ mercado_libre │ laptop       │ search             │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ mini_pc      │ search             │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ pc           │ search             │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ laptop       │ search__attributes │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ mini_pc      │ search__attributes │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ pc           │ search__attributes │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ laptop       │ seller             │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ mini_pc      │ seller             │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# │ mercado_libre │ pc           │ seller             │ BASE TABLE │ NULL                         │ NULL                 │ NULL                      │ NULL                     │ NULL                   │ YES                │ NO       │ NULL          │ NULL          │
# └───────────────┴──────────────┴────────────────────┴────────────┴──────────────────────────────┴──────────────────────┴───────────────────────────┴──────────────────────────┴────────────────────────┴────────────────────┴──────────┴───────────────┴───────────────┘

# %%
mini_pc.search__attributes

# %% [markdown]
# Las 3 tablas existen para las 3 búsquedas

# %%
base.close()

# %% [markdown]
# Cerramos la conexión

# %% [markdown]
# ## 6). Configurar el archivo "profiles.yml"
#
# Agregar el Path de la base de datos duckdb al Profiles
#
# ```yaml
# ml_transformations:
#   outputs:
#     dev:
#       type: duckdb
#       path: /home/juan/UCCuyo/BaseDeDatos2024/mercado_libre.duckdb
#       threads: 1
#
#     prod:
#       type: duckdb
#       path: prod.duckdb
#       threads: 4
#
#   target: dev
# ```

# %% [markdown]
# ## 7).. Testear que DBT se pueda conectar a la base de datos
#
# ### a). Ir al path del proyecto de DBT
#
# ```powershell
# 01-bases-de-datos-py3.11juan@BOOK-NFF0K06361:~/UCCuyo/BaseDeDatos2024$ cd ml_transformations
# 01-bases-de-datos-py3.11juan@BOOK-NFF0K06361:~/UCCuyo/BaseDeDatos2024/ml_transformations$
# ```
#
# ### b). Ejecutar "dbt debug" para ver si se conectó exitosamente (Asegurarme que no haya ninguna conexión abierta a la base)
#
# ```powershell
# 01-bases-de-datos-py3.11juan@BOOK-NFF0K06361:~/UCCuyo/BaseDeDatos2024/ml_transformations$ dbt debug
# 01:22:27  Running with dbt=1.8.0
# 01:22:28  dbt version: 1.8.0
# 01:22:28  python version: 3.11.0rc1
# 01:22:28  python path: /home/juan/.cache/pypoetry/virtualenvs/01-bases-de-datos-dkH_pZ-u-py3.11/bin/python
# 01:22:28  os info: Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# 01:22:28  Using profiles dir at /home/juan/.dbt
# 01:22:28  Using profiles.yml file at /home/juan/.dbt/profiles.yml
# 01:22:28  Using dbt_project.yml file at /home/juan/UCCuyo/BaseDeDatos2024/ml_transformations/dbt_project.yml
# 01:22:28  adapter type: duckdb
# 01:22:28  adapter version: 1.9.0
# 01:22:28  Configuration:
# 01:22:28    profiles.yml file [OK found and valid]
# 01:22:28    dbt_project.yml file [OK found and valid]
# 01:22:28  Required dependencies:
# 01:22:28   - git [OK found]
#
# 01:22:28  Connection:
# 01:22:28    database: mercado_libre
# 01:22:28    schema: main
# 01:22:28    path: /home/juan/UCCuyo/BaseDeDatos2024/mercado_libre.duckdb
# 01:22:28    config_options: None
# 01:22:28    extensions: None
# 01:22:28    settings: {}
# 01:22:28    external_root: .
# 01:22:28    use_credential_provider: None
# 01:22:28    attach: None
# 01:22:28    filesystems: None
# 01:22:28    remote: None
# 01:22:28    plugins: None
# 01:22:28    disable_transactions: False
# 01:22:28  Registered adapter: duckdb=1.9.0
# 01:22:28    Connection test: [OK connection ok]
#
# 01:22:28  All checks passed!
# ```

# %% [markdown]
# ## 8). Modificar el Archivo "schema.yml" para poder leer las tablas generadas en el proceso de ingesta creando "Sources":

# %% [markdown]
# ### a). ¿Qué son las Fuentes (Sources) en dbt?
#
# En dbt, una *source* hace referencia a las bases de datos, esquemas y tablas en tu base de datos conectada desde donde dbt puede leer datos. Se definen en archivos YAML y se referencian en la creación de modelos.  Esto facilita la reutilización, el mantenimiento y la consistencia del código.
#
# **Definición de Sources:**
#
# Las *sources* se definen en archivos `sources.yml` bajo la clave `sources:`. Un archivo `sources.yml` básico incluye:
#
# *   `version: 2`: Versión del archivo `sources.yml`.  Actualmente, la versión 2 es la única soportada.
# *   `sources:`: Lista de sources.
#     *   `name:`: Nombre de la *source*. **Obligatorio**.
#     *   `database:`: Nombre de la base de datos.
#     *   `schema:`: Nombre del esquema.
#     *   `tables:`: Lista de tablas.
#         *   `name:`: Nombre de la tabla. **Obligatorio**.
#
# **Propiedades Adicionales:**
#
# Además de las propiedades básicas, se pueden agregar:
#
# *   `description:`: Descripción de la *source* o tabla.  Útil para la documentación.
# *   `freshness:`: Configuraciones para verificar la frescura de los datos.
# *   `tests:`: Pruebas para validar la calidad de los datos.
#
#
# **Beneficios de Usar Sources:**
#
# *   **Reutilización:** Define las *sources* una sola vez y úsalas en múltiples modelos.
# *   **Mantenimiento:** Separa la ubicación de los datos del código dbt, facilitando las actualizaciones.
# *   **Consistencia:** Centraliza la información de conexión, asegurando la uniformidad en el proyecto.
# *   **Lineaje:** Influye en el orden de ejecución de los modelos (DAGs de dbt).
#
# **Referenciando Sources en Modelos:**
#
# Se utiliza la función Jinja `source()` para referenciar las *sources* en los modelos:
#
# ```sql
# {{ source('nombre_de_la_source', 'nombre_de_la_tabla') }}
# ```
#
# **Ejemplo:**
#
# ```sql
# SELECT * FROM {{ source('Producto', 'items') }}
# ```
#
# **Solución de Problemas:**
#
# Si se producen errores al referenciar *sources*, verificar:
#
# *   Que la *source* exista en el archivo `sources.yml`.
# *   Que la *source* exista en la base de datos.
# *   Que el usuario de dbt tenga acceso a la *source*.
# *   Que las mayúsculas y minúsculas coincidan entre el código y el archivo `sources.yml`.
# *   La correcta indentación en el archivo YAML.
#
#
# El uso de *sources* es una práctica recomendada en dbt para un desarrollo más eficiente, mantenible y consistente.

# %% [markdown]
# ```yaml
# version: 2
#
# sources:
#   - name: laptop
#     schema: laptop
#     tables:
#       - name: search
#         description: "Información cruda sobre las búsquedas realizadas para laptops proveniente de la API de Mercado Libre."
#       - name: search_attributes
#         description: "Atributos adicionales asociados a las búsquedas de laptops, provenientes de la API de Mercado Libre."
#       - name: sellers
#         description: "Información sobre los vendedores de laptops obtenida de la API de Mercado Libre."
#
#   - name: mini_pc
#     schema: mini_pc
#     tables:
#       - name: search
#         description: "Información cruda sobre las búsquedas realizadas para mini PCs proveniente de la API de Mercado Libre."
#       - name: search_attributes
#         description: "Atributos adicionales asociados a las búsquedas de mini PCs, provenientes de la API de Mercado Libre."
#       - name: sellers
#         description: "Información sobre los vendedores de mini PCs obtenida de la API de Mercado Libre."
#
#   - name: pc
#     schema: pc
#     tables:
#       - name: search
#         description: "Información cruda sobre las búsquedas realizadas para PCs proveniente de la API de Mercado Libre."
#       - name: search_attributes
#         description: "Atributos adicionales asociados a las búsquedas de PCs, provenientes de la API de Mercado Libre."
#       - name: sellers
#         description: "Información sobre los vendedores de PCs obtenida de la API de Mercado Libre."
# ```

# %% [markdown]
# ### b). ¿Qué son los modelos (Models) en dbt?
#
#
# En DBT, un **modelo** es un archivo SQL que contiene la lógica de transformación de datos que queres aplicar a tus tablas en el Data Warehouse. En esencia, un modelo define cómo transformar, limpiar o preparar los datos para análisis y reportes.
# ---
#
# #### Características Principales de un Modelo en DBT
#
# 1. **Archivo SQL**: Cada modelo en DBT es un archivo `.sql` que contiene una consulta SQL que transforma los datos en el almacén de datos.
#
# 2. **Materialización**: DBT materializa los modelos en el almacén de datos como:
#
#    - **Vista (`view`)**: Almacena el SQL como una vista.
#
#    - **Tabla (`table`)**: Ejecuta la consulta y almacena el resultado como una tabla permanente.
#
#    - **Incremental (`incremental`)**: Solo actualiza los datos nuevos o cambiados.
#
#    - **Ephemeral**: Modelo temporal que no se materializa en el almacén, sino que es usado por otros modelos.
#
# 3. **Dependencias**: DBT permite a los modelos referenciar otros modelos mediante la función `ref`, que gestiona dependencias entre ellos. Por ejemplo:
#
#    ```sql
#    -- modelo_ventas.sql
#    select *
#    from {{ ref('modelo_clientes') }}
#    ```
#
#    Aquí, `modelo_ventas` depende de `modelo_clientes`, y DBT sabe en qué orden ejecutarlos.
#
# 4. **Facilita el Versionado y el Linaje**: Al definir cada transformación en su propio archivo, puedes visualizar el linaje de datos, ver qué modelos alimentan a otros, y versionar cada transformación.
#
# 5. **Mejora la Escalabilidad y Reusabilidad**: Separar la lógica en modelos hace que sea fácil reutilizar, actualizar o extender transformaciones en el tiempo sin afectar otros elementos.

# %% [markdown]
# ### c). Arquitectura de Datos: Bronze, Silver y Gold
#
# La arquitectura **Bronze, Silver y Gold** es un enfoque común para la organización y transformación de datos dentro de un **Data Lakehouse** o un **Modern Data Stack**. Esta estructura permite mover los datos desde su forma más cruda hasta un formato listo para el análisis y consumo por usuarios de negocio.
#
# ### 1. Capa Bronze (Bronze Layer)
# - **Propósito**:
#   - Almacenar los datos en su forma más cruda, tal como llegan de las fuentes.
# - **Características**:
#   - Datos sin procesar, sin modificaciones, que incluyen errores y duplicados.
#   - Preserva toda la información posible para futuros análisis.
# - **Ejemplos**:
#   - Logs de eventos, archivos CSV originales, datos crudos extraídos de APIs.
#
# ### 2. Capa Silver (Silver Layer)
# - **Propósito**:
#   - Limpieza y normalización de los datos para que estén listos para transformaciones más avanzadas.
# - **Características**:
#   - Datos sin duplicados, con valores nulos manejados y columnas estandarizadas.
#   - Realiza unificación y limpieza inicial de los datos.
# - **Ejemplos**:
#   - Datos de ventas sin errores, con nombres de columnas estandarizados.
#
# ### 3. Capa Gold (Gold Layer)
# - **Propósito**:
#   - Producir vistas enriquecidas listas para el análisis de negocio.
# - **Características**:
#   - Los datos se transforman en métricas agregadas y cálculos avanzados.
#   - Diseñados para ser consumidos directamente en dashboards, reportes y aplicaciones de BI.
# - **Ejemplos**:
#   - Resúmenes de ventas por región y trimestre, etc.
#
# ### Ventajas de la Arquitectura Bronze, Silver y Gold
# - **Trazabilidad y Auditoría**: Cada capa preserva un nivel de transformación, facilitando la trazabilidad de los datos.
# - **Eficiencia**: Al dividir los datos en capas, se optimiza el procesamiento y se minimizan recalculaciones innecesarias.
# - **Modularidad**: Cada capa tiene un propósito específico, lo que facilita la reutilización y el mantenimiento.
#
# ### Comparación con dbt
# - **Bronze**: Equivalente a la definición de **sources** en dbt, donde los datos se toman directamente de las fuentes.
#
# - **Silver**: Similar a los **modelos de staging**, donde los datos se limpian y normalizan.
#
# - **Gold**: Equivalente a los **data marts**, donde los datos se preparan para el consumo final y análisis de negocio.

# %% [markdown]
# ## 9). Seleccionar las columnas relevantes

# %% [markdown]
# ### a). Seleccionar las columnas de "Search"

# %%
base = duckdb.connect('mercado_libre.duckdb')

# %%
base.sql('''
SELECT *
FROM laptop.search
LIMIT 1
''')
# Out:
# ┌───────────────┬───────────────────────────────────────────────────────────────────────┬───────────┬──────────────────────────────┬────────────────────┬─────────────────┬───────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬─────────────┬─────────┬─────────────┬───────────────┬────────────────────────────────────────────────────────────────┬─────────────┬───────────────┬───────────┬────────────────┬──────────────────────┬────────────────────┬──────────────────────────────────┬────────────────────────────────────┬──────────────────────────────────┬─────────────────────────┬─────────────────────────────────┬────────────────────────────┬──────────────────┬──────────────────────────────────────┬────────────────────────────────────┬────────────────────┬───────────────────┬─────────────────────┬──────────────────┬─────────────────────┬─────────────────────────┬─────────────────────────┬─────────────────────────┬────────────────┬──────────────────────────┬──────────────────────────┬────────────┬──────────────────┬────────────────────────┬──────────────────────┬────────────────────┬───────────────────────────┬───────────────────────────────────────────────┬──────────────────────────────────────────────────┬─────────────────┬──────────────┬────────────────────┬────────────────┬────────────────────────────────────┬────────────────────────────────────────────┬─────────────────────────────────────┬───────────────────────────────────┬────────────────────────────────────────┬─────────────────────────────────┬────────────────────────────────────────────────────┬─────────────────────────────────────────┬──────────────────────────┬──────────────────────────────────────┬──────────────────────────────────────────────────┬──────────────────────────────────────────────────────┬──────────────────────────────┐
# │      id       │                                 title                                 │ condition │         thumbnail_id         │ catalog_product_id │ listing_type_id │                            sanitized_title                            │                                                                     permalink                                                                     │ buying_mode │ site_id │ category_id │   domain_id   │                           thumbnail                            │ currency_id │ order_backend │   price   │ original_price │ sale_price__price_id │ sale_price__amount │ sale_price__conditions__eligible │ sale_price__conditions__start_time │ sale_price__conditions__end_time │ sale_price__currency_id │ sale_price__payment_method_type │ sale_price__regular_amount │ sale_price__type │ sale_price__metadata__promotion_type │ sale_price__metadata__promotion_id │ available_quantity │ official_store_id │ official_store_name │ use_thumbnail_id │ accepts_mercadopago │ shipping__store_pick_up │ shipping__free_shipping │ shipping__logistic_type │ shipping__mode │ shipping__shipping_score │        stop_time         │ seller__id │ seller__nickname │ installments__quantity │ installments__amount │ installments__rate │ installments__currency_id │ installments__metadata__meliplus_installments │ installments__metadata__additional_bank_interest │ catalog_listing │ inventory_id │    _dlt_load_id    │    _dlt_id     │ sale_price__metadata__funding_mode │ sale_price__metadata__discount_meli_amount │ sale_price__metadata__experiment_id │ sale_price__metadata__campaign_id │ sale_price__metadata__order_item_price │ sale_price__metadata__variation │ sale_price__metadata__campaign_discount_percentage │ sale_price__metadata__campaign_end_date │ original_price__v_double │ sale_price__regular_amount__v_double │ sale_price__metadata__order_item_price__v_double │ sale_price__metadata__discount_meli_amount__v_double │ installments__rate__v_double │
# │    varchar    │                                varchar                                │  varchar  │           varchar            │      varchar       │     varchar     │                                varchar                                │                                                                      varchar                                                                      │   varchar   │ varchar │   varchar   │    varchar    │                            varchar                             │   varchar   │     int64     │  double   │     int64      │       varchar        │       double       │             boolean              │      timestamp with time zone      │     timestamp with time zone     │         varchar         │             varchar             │           int64            │     varchar      │               varchar                │              varchar               │       int64        │       int64       │       varchar       │     boolean      │       boolean       │         boolean         │         boolean         │         varchar         │    varchar     │          int64           │ timestamp with time zone │   int64    │     varchar      │         int64          │        double        │       int64        │          varchar          │                    boolean                    │                     boolean                      │     boolean     │   varchar    │      varchar       │    varchar     │              varchar               │                   int64                    │               varchar               │              varchar              │                 int64                  │             varchar             │                       double                       │        timestamp with time zone         │          double          │                double                │                      double                      │                        double                        │            double            │
# ├───────────────┼───────────────────────────────────────────────────────────────────────┼───────────┼──────────────────────────────┼────────────────────┼─────────────────┼───────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────┼─────────────┼───────────────┼────────────────────────────────────────────────────────────────┼─────────────┼───────────────┼───────────┼────────────────┼──────────────────────┼────────────────────┼──────────────────────────────────┼────────────────────────────────────┼──────────────────────────────────┼─────────────────────────┼─────────────────────────────────┼────────────────────────────┼──────────────────┼──────────────────────────────────────┼────────────────────────────────────┼────────────────────┼───────────────────┼─────────────────────┼──────────────────┼─────────────────────┼─────────────────────────┼─────────────────────────┼─────────────────────────┼────────────────┼──────────────────────────┼──────────────────────────┼────────────┼──────────────────┼────────────────────────┼──────────────────────┼────────────────────┼───────────────────────────┼───────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────┼────────────────────┼────────────────┼────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────┼───────────────────────────────────┼────────────────────────────────────────┼─────────────────────────────────┼────────────────────────────────────────────────────┼─────────────────────────────────────────┼──────────────────────────┼──────────────────────────────────────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼──────────────────────────────┤
# │ MLA1424712885 │ Notebook Exo Smart T38 Intel N4020 4gb Ssd128gb Windows 11 Color Gris │ new       │ 620219-MLA54973743242_042023 │ MLA22826188        │ gold_pro        │ notebook-exo-smart-t38-intel-n4020-4gb-ssd128gb-windows-11-color-gris │ https://www.mercadolibre.com.ar/notebook-exo-smart-t38-intel-n4020-4gb-ssd128gb-windows-11-color-gris/p/MLA22826188#wid=MLA1424712885&sid=unknown │ buy_it_now  │ MLA     │ MLA1652     │ MLA-NOTEBOOKS │ http://http2.mlstatic.com/D_620219-MLA54973743242_042023-I.jpg │ ARS         │             1 │ 414399.26 │         559999 │                      │          414399.26 │ true                             │ 2024-10-28 00:00:00-03             │ 2024-11-27 23:59:59-03           │ ARS                     │ TMP                             │                     559999 │ promotion        │ custom                               │ OFFER-MLA1424712885-10200693227    │                250 │               341 │ EXO                 │ true             │ true                │ false                   │ true                    │ cross_docking           │ me2            │                       -1 │ 2044-04-28 01:00:00-03   │  180214913 │ EXO SA           │                     12 │             34533.27 │                  0 │ ARS                       │ false                                         │ false                                            │ true            │ LLEM57590    │ 1730421501.3225703 │ GCY1SBkSzYYtlA │ NULL                               │                                       NULL │ NULL                                │ NULL                              │                                   NULL │ NULL                            │                                               NULL │ NULL                                    │                     NULL │                                 NULL │                                             NULL │                                                 NULL │                         NULL │
# └───────────────┴───────────────────────────────────────────────────────────────────────┴───────────┴──────────────────────────────┴────────────────────┴─────────────────┴───────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴─────────────┴─────────┴─────────────┴───────────────┴────────────────────────────────────────────────────────────────┴─────────────┴───────────────┴───────────┴────────────────┴──────────────────────┴────────────────────┴──────────────────────────────────┴────────────────────────────────────┴──────────────────────────────────┴─────────────────────────┴─────────────────────────────────┴────────────────────────────┴──────────────────┴──────────────────────────────────────┴────────────────────────────────────┴────────────────────┴───────────────────┴─────────────────────┴──────────────────┴─────────────────────┴─────────────────────────┴─────────────────────────┴─────────────────────────┴────────────────┴──────────────────────────┴──────────────────────────┴────────────┴──────────────────┴────────────────────────┴──────────────────────┴────────────────────┴───────────────────────────┴───────────────────────────────────────────────┴──────────────────────────────────────────────────┴─────────────────┴──────────────┴────────────────────┴────────────────┴────────────────────────────────────┴────────────────────────────────────────────┴─────────────────────────────────────┴───────────────────────────────────┴────────────────────────────────────────┴─────────────────────────────────┴────────────────────────────────────────────────────┴─────────────────────────────────────────┴──────────────────────────┴──────────────────────────────────────┴──────────────────────────────────────────────────┴──────────────────────────────────────────────────────┴──────────────────────────────┘

# %% [markdown]
# Las columnas relevantes son:
# 1. id
# 2. title
# 3. condtion
# 4. catalog_product_id
# 5. listing_type_id
# 6. category_id
# 7. domain_id
# 8. price
# 9. original_price
# 10. sale_price__price_id
# 11. sale_price__amount
# 12. available_quantity
# 13. seller__id
# 14. seller__nickname
# 15. _dlt_load_id
# 15. _dlt_id

# %%
base.close()

# %% [markdown]
# ### b). Seleccionar las columnas de "Search Attributes"

# %%
base = duckdb.connect('mercado_libre.duckdb')

# %%
base.sql('''
SELECT *
FROM laptop.search__attributes
LIMIT 5
''')
# Out:
# ┌────────────────┬──────────────────────────────┬──────────┬───────────────┬────────────────────┬──────────────────────┬──────────────────┬────────────┬────────────────┬───────────────┬────────────────┬──────────────────────┬────────────────────┬────────────────────────────────┐
# │       id       │             name             │ value_id │  value_name   │ attribute_group_id │ attribute_group_name │      source      │ value_type │ _dlt_parent_id │ _dlt_list_idx │    _dlt_id     │ value_struct__number │ value_struct__unit │ value_struct__number__v_double │
# │    varchar     │           varchar            │ varchar  │    varchar    │      varchar       │       varchar        │      int64       │  varchar   │    varchar     │     int64     │    varchar     │        int64         │      varchar       │             double             │
# ├────────────────┼──────────────────────────────┼──────────┼───────────────┼────────────────────┼──────────────────────┼──────────────────┼────────────┼────────────────┼───────────────┼────────────────┼──────────────────────┼────────────────────┼────────────────────────────────┤
# │ BRAND          │ Marca                        │ 27222    │ EXO           │ OTHERS             │ Otros                │                1 │ string     │ GCY1SBkSzYYtlA │             0 │ y2aFiuP69UZ3jA │                 NULL │ NULL               │                           NULL │
# │ COLOR          │ Color                        │ 283165   │ Gris          │ OTHERS             │ Otros                │                1 │ string     │ GCY1SBkSzYYtlA │             1 │ qjrcSESk/xdr5w │                 NULL │ NULL               │                           NULL │
# │ GTIN           │ Código universal de producto │ NULL     │ 7797678020029 │ OTHERS             │ Otros                │ 6402814585011704 │ string     │ GCY1SBkSzYYtlA │             2 │ HRrO4NUv0vK2/w │                 NULL │ NULL               │                           NULL │
# │ ITEM_CONDITION │ Condición del ítem           │ 2230284  │ Nuevo         │ OTHERS             │ Otros                │ 6402814585011704 │ list       │ GCY1SBkSzYYtlA │             3 │ dKjEvN2HBdUfYQ │                 NULL │ NULL               │                           NULL │
# │ LINE           │ Línea                        │ 196      │ Smart         │ OTHERS             │ Otros                │                1 │ string     │ GCY1SBkSzYYtlA │             4 │ RDRklszngfSi2Q │                 NULL │ NULL               │                           NULL │
# └────────────────┴──────────────────────────────┴──────────┴───────────────┴────────────────────┴──────────────────────┴──────────────────┴────────────┴────────────────┴───────────────┴────────────────┴──────────────────────┴────────────────────┴────────────────────────────────┘

# %% [markdown]
# Son la columnas "id" y "name" las mismas?

# %%
base.sql('''
SELECT id, name, count(*)
FROM laptop.search__attributes
GROUP BY ALL
ORDER BY 1, 2
''')
# Out:
# ┌────────────────────┬──────────────────────────────┬──────────────┐
# │         id         │             name             │ count_star() │
# │      varchar       │           varchar            │    int64     │
# ├────────────────────┼──────────────────────────────┼──────────────┤
# │ ALPHANUMERIC_MODEL │ Modelo alfanumérico          │          820 │
# │ BRAND              │ Marca                        │         1098 │
# │ CABLE_LENGTH       │ Largo del cable              │            2 │
# │ COLOR              │ Color                        │          623 │
# │ DETAILED_MODEL     │ Modelo detallado             │          261 │
# │ GTIN               │ Código universal de producto │          627 │
# │ ITEM_CONDITION     │ Condición del ítem           │         1098 │
# │ LINE               │ Línea                        │         1006 │
# │ MAIN_COLOR         │ Color principal              │          533 │
# │ MODEL              │ Modelo                       │         1098 │
# │ PACKAGE_LENGTH     │ Largo del paquete            │           46 │
# │ PACKAGE_WEIGHT     │ Peso del paquete             │           46 │
# │ PROCESSOR_BRAND    │ Marca del procesador         │         1096 │
# │ PROCESSOR_LINE     │ Línea del procesador         │         1086 │
# │ PROCESSOR_MODEL    │ Modelo del procesador        │         1043 │
# │ SALE_FORMAT        │ Formato de venta             │            1 │
# │ UNITS_PER_PACK     │ Unidades por pack            │            1 │
# │ WEIGHT             │ Peso                         │         1023 │
# ├────────────────────┴──────────────────────────────┴──────────────┤
# │ 18 rows                                                3 columns │
# └──────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Si, son las mismas, por lo tanto, tiene sentido solo incluir una de ellas.

# %% [markdown]
# Tiene sentido incorporar "attribute_group_id"?

# %%
base.sql('''
SELECT attribute_group_id, count(*)
FROM laptop.search__attributes
GROUP BY ALL
ORDER BY 1, 2
''')
# Out:
# ┌────────────────────┬──────────────┐
# │ attribute_group_id │ count_star() │
# │      varchar       │    int64     │
# ├────────────────────┼──────────────┤
# │                    │            4 │
# │ OTHERS             │        11504 │
# └────────────────────┴──────────────┘

# %% [markdown]
# Las columnas que se van a utilizar son:
#
# 1. id
# 2. value_name
# 3. _dlt_parent_id
# 4. _dlt_id

# %% [markdown]
# ### c). Seleccionar las columnas de "Seller"

# %%
base = duckdb.connect('mercado_libre.duckdb')

# %%
base.sql('''
SELECT * EXCLUDE(permalink)
FROM laptop.seller
LIMIT 1
''')
# Out:
# ┌───────────┬──────────┬────────────┬───────────────┬────────────────┬───────────┬─────────┬──────────────────────────────────────────┬─────────────────────────────┬────────────────────────────────────────┬─────────────────────────────────────────┬────────────────────────────────────────┬─────────────────────┬────────────────────┬────────────────┐
# │    id     │ nickname │ country_id │ address__city │ address__state │ user_type │ site_id │                permalink                 │ seller_reputation__level_id │ seller_reputation__power_seller_status │ seller_reputation__transactions__period │ seller_reputation__transactions__total │ status__site_status │    _dlt_load_id    │    _dlt_id     │
# │   int64   │ varchar  │  varchar   │    varchar    │    varchar     │  varchar  │ varchar │                 varchar                  │           varchar           │                varchar                 │                 varchar                 │                 int64                  │       varchar       │      varchar       │    varchar     │
# ├───────────┼──────────┼────────────┼───────────────┼────────────────┼───────────┼─────────┼──────────────────────────────────────────┼─────────────────────────────┼────────────────────────────────────────┼─────────────────────────────────────────┼────────────────────────────────────────┼─────────────────────┼────────────────────┼────────────────┤
# │ 180214913 │ EXO SA   │ AR         │ Boedo         │ AR-C           │ brand     │ MLA     │ http://perfil.mercadolibre.com.ar/EXO+SA │ 5_green                     │ platinum                               │ historic                                │                                  11878 │ active              │ 1730421501.3225703 │ 49hFFJ3EQLxaoA │
# └───────────┴──────────┴────────────┴───────────────┴────────────────┴───────────┴─────────┴──────────────────────────────────────────┴─────────────────────────────┴────────────────────────────────────────┴─────────────────────────────────────────┴────────────────────────────────────────┴─────────────────────┴────────────────────┴────────────────┘

# %% [markdown]
# Todas las columnas a utilizar son importantes excepto "permalink". A esta columna la podemos excluir con:
#
# ```sql
# SELECT * EXCLUDE(permalink)
# FROM laptop.seller
# ```

# %%
base.close()

# %% [markdown]
# ## 11. Crear los Modelos "Silver"

# %% [markdown]
# #### a). Crear una carpeta con el nombre "silver" dentro de la carpeta "models"

# %% [markdown]
# #### b). Modificar el archivo "dbt_project.yml"

# %% [markdown]
# Agregar:
# ```yaml
#     silver:
#       +schema: silver
# ```
#
# Cuando configurás `+schema: silver` para una carpeta o grupo de modelos, le estás diciendo a dbt que todos los modelos que se encuentren en esa carpeta deben ser materializados en el esquema silver.

# %% [markdown]
# ### c). Crear los modelos en .sql:
#
#
# #### `search.sql`
# ```sql
# -- Modelo 1: Unión de las tablas 'search' de los esquemas laptop, mini_pc y pc
# {{ config(materialized='table') }}
#
# WITH laptop_search AS (
#     SELECT id, title, condition, catalog_product_id, listing_type_id, category_id, domain_id, price, original_price,
#            sale_price__price_id, sale_price__amount, available_quantity, seller__id, seller__nickname, _dlt_load_id, _dlt_id, 'laptop' AS product_type
#     FROM {{ source('laptop', 'search') }}
# ),
# mini_pc_search AS (
#     SELECT id, title, condition, catalog_product_id, listing_type_id, category_id, domain_id, price, original_price,
#            sale_price__price_id, sale_price__amount, available_quantity, seller__id, seller__nickname, _dlt_load_id, _dlt_id, 'mini_pc' AS product_type
#     FROM {{ source('mini_pc', 'search') }}
# ),
# pc_search AS (
#     SELECT id, title, condition, catalog_product_id, listing_type_id, category_id, domain_id, price, original_price,
#            sale_price__price_id, sale_price__amount, available_quantity, seller__id, seller__nickname, _dlt_load_id, _dlt_id, 'pc' AS product_type
#     FROM {{ source('pc', 'search') }}
# )
#
# SELECT id, title, condition, catalog_product_id, listing_type_id, category_id, domain_id, price, original_price,
#        sale_price__price_id, sale_price__amount, available_quantity, seller__id, seller__nickname, _dlt_load_id, _dlt_id, product_type
# FROM laptop_search
# UNION ALL
# SELECT id, title, condition, catalog_product_id, listing_type_id, category_id, domain_id, price, original_price,
#        sale_price__price_id, sale_price__amount, available_quantity, seller__id, seller__nickname, _dlt_load_id, _dlt_id, product_type
# FROM mini_pc_search
# UNION ALL
# SELECT id, title, condition, catalog_product_id, listing_type_id, category_id, domain_id, price, original_price,
#        sale_price__price_id, sale_price__amount, available_quantity, seller__id, seller__nickname, _dlt_load_id, _dlt_id, product_type
# FROM pc_search
#
# ```
#
# #### `search_attributes.sql`
#
# ```SQL
# -- Modelo 2: Unión de las tablas 'search__attributes' de los esquemas laptop, mini_pc y pc
# {{ config(materialized='view') }}
#
# WITH laptop_search_attributes AS (
#     SELECT id, value_name, _dlt_parent_id, _dlt_id, 'laptop' AS product_type
#     FROM {{ source('laptop', 'search__attributes') }}
# ),
# mini_pc_search_attributes AS (
#     SELECT id, value_name, _dlt_parent_id, _dlt_id, 'mini_pc' AS product_type
#     FROM {{ source('mini_pc', 'search__attributes') }}
# ),
# pc_search_attributes AS (
#     SELECT id, value_name, _dlt_parent_id, _dlt_id, 'pc' AS product_type
#     FROM {{ source('pc', 'search__attributes') }}
# )
#
# SELECT id, value_name, _dlt_parent_id, _dlt_id, product_type FROM laptop_search_attributes
# UNION ALL
# SELECT id, value_name, _dlt_parent_id, _dlt_id, product_type FROM mini_pc_search_attributes
# UNION ALL
# SELECT id, value_name, _dlt_parent_id, _dlt_id, product_type FROM pc_search_attributes
# ```
#
# #### `seller.sql`
#
# ```sql
# -- Modelo 3: Unión de las tablas 'seller' de los esquemas laptop, mini_pc y pc
# {{ config(materialized='view') }}
#
# WITH laptop_seller AS (
#     SELECT * EXCLUDE(permalink), 'laptop' AS product_type
#     FROM {{ source('laptop', 'seller') }}
# ),
# mini_pc_seller AS (
#     SELECT  * EXCLUDE(permalink), 'mini_pc' AS product_type
#     FROM {{ source('mini_pc', 'seller') }}
# ),
# pc_seller AS (
#     SELECT * EXCLUDE(permalink), 'pc' AS product_type
#     FROM {{ source('pc', 'seller') }}
# )
#
# SELECT * FROM laptop_seller
# UNION ALL
# SELECT * FROM mini_pc_seller
# UNION ALL
# SELECT * FROM pc_seller
# ```

# %% [markdown]
# ### d). Ejecutar el código de DBT para crear los modelos
#
# ### Comandos de DBT:
#
# | Comando         | Descripción                                                                                  |
# |-----------------|----------------------------------------------------------------------------------------------|
# | `dbt init`      | Inicializa un nuevo proyecto DBT.                                                            |
# | `dbt run`       | Ejecuta y materializa los modelos en la base de datos.                                       |
# | `dbt test`      | Ejecuta las pruebas de datos para verificar calidad y consistencia.                          |
# | `dbt build`     | Ejecuta `run` y `test` en un solo paso para construir y validar.                             |
# | `dbt seed`      | Carga archivos CSV en tablas de la base de datos.                                            |
# | `dbt snapshot`  | Crea snapshots para un seguimiento histórico de los datos.                                   |
# | `dbt docs`      | Genera y visualiza documentación interactiva del proyecto.                                   |
# | `dbt debug`     | Verifica la configuración del proyecto y la conexión a la base de datos.                     |
# | `dbt compile`   | Compila modelos SQL en archivos SQL puros.                                                   |
# | `dbt clean`     | Limpia archivos generados, incluyendo `target`.                                              |
#
#
# #### `search.sql`
# ```powershell
# 01-bases-de-datos-py3.11juan@BOOK-NFF0K06361:~/UCCuyo/BaseDeDatos2024/ml_transformations$ dbt run --select search
# 03:20:55  Running with dbt=1.8.0
# 03:20:56  Registered adapter: duckdb=1.9.0
# 03:20:56  Found 3 models, 4 data tests, 9 sources, 416 macros
# 03:20:56
# 03:20:56  Concurrency: 1 threads (target='dev')
# 03:20:56
# 03:20:56  1 of 1 START sql table model main_silver.search ................................ [RUN]
# 03:20:57  1 of 1 OK created sql table model main_silver.search ........................... [OK in 0.27s]
# 03:20:57
# 03:20:57  Finished running 1 table model in 0 hours 0 minutes and 0.68 seconds (0.68s).
# 03:20:57
# 03:20:57  Completed successfully
# 03:20:57
# 03:20:57  Done. PASS=1 WARN=0 ERROR=0 SKIP=0 TOTAL=1
# 01-bases-de-datos-py3.11juan@BOOK-NFF0K06361:~/UCCuyo/BaseDeDatos2024/ml_transformations$
# ```
#
# #### `search_attributes.sql`
# ```powershell
# 01-bases-de-datos-py3.11juan@BOOK-NFF0K06361:~/UCCuyo/BaseDeDatos2024/ml_transformations$ dbt run --select search_attributes
# 15:29:34  Running with dbt=1.8.0
# 15:29:34  Registered adapter: duckdb=1.9.0
# 15:29:35  Found 4 models, 4 data tests, 9 sources, 416 macros
# 15:29:35
# 15:29:35  Concurrency: 1 threads (target='dev')
# 15:29:35
# 15:29:35  1 of 1 START sql view model main_silver.search_attributes ...................... [RUN]
# 15:29:36  1 of 1 OK created sql view model main_silver.search_attributes ................. [OK in 0.37s]
# 15:29:36
# 15:29:36  Finished running 1 view model in 0 hours 0 minutes and 0.80 seconds (0.80s).
# 15:29:36
# 15:29:36  Completed successfully
# 15:29:36
# 15:29:36  Done. PASS=1 WARN=0 ERROR=0 SKIP=0 TOTAL=1
# ```
# #### `seller.sql`
#
# ```powershell
# 01-bases-de-datos-py3.11juan@BOOK-NFF0K06361:~/UCCuyo/BaseDeDatos2024/ml_transformations$ dbt run --select seller
# 15:45:22  Running with dbt=1.8.0
# 15:45:22  Registered adapter: duckdb=1.9.0
# 15:45:23  Found 5 models, 4 data tests, 9 sources, 416 macros
# 15:45:23
# 15:45:24  Concurrency: 1 threads (target='dev')
# 15:45:24
# 15:45:24  1 of 1 START sql view model main_silver.seller ................................. [RUN]
# 15:45:24  1 of 1 OK created sql view model main_silver.seller ............................ [OK in 0.30s]
# 15:45:24
# 15:45:24  Finished running 1 view model in 0 hours 0 minutes and 1.02 seconds (1.02s).
# 15:45:24
# 15:45:24  Completed successfully
# 15:45:24
# 15:45:24  Done. PASS=1 WARN=0 ERROR=0 SKIP=0 TOTAL=1
# ```

# %% [markdown]
# ### f). Verificar que los modelos "Silver" se hayan creado Correctamente

# %%
base = duckdb.connect('mercado_libre.duckdb')

# %%
base.sql('''
SELECT DISTINCT table_schema
FROM information_schema.tables
''')
# Out:
# ┌──────────────┐
# │ table_schema │
# │   varchar    │
# ├──────────────┤
# │ main         │
# │ main_silver  │
# │ laptop       │
# │ mini_pc      │
# │ pc           │
# └──────────────┘

# %%
base.sql('''
SELECT *
FROM main_silver.search
limit 2
''')
# Out:
# ┌───────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────┬────────────────────┬─────────────────┬─────────────┬───────────────┬───────────┬────────────────┬──────────────────────┬────────────────────┬────────────────────┬────────────┬──────────────────┬────────────────────┬────────────────┬──────────────┐
# │      id       │                                                          title                                                          │ condition │ catalog_product_id │ listing_type_id │ category_id │   domain_id   │   price   │ original_price │ sale_price__price_id │ sale_price__amount │ available_quantity │ seller__id │ seller__nickname │    _dlt_load_id    │    _dlt_id     │ product_type │
# │    varchar    │                                                         varchar                                                         │  varchar  │      varchar       │     varchar     │   varchar   │    varchar    │  double   │     double     │       varchar        │       double       │       int64        │   int64    │     varchar      │      varchar       │    varchar     │   varchar    │
# ├───────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────┼─────────────────┼─────────────┼───────────────┼───────────┼────────────────┼──────────────────────┼────────────────────┼────────────────────┼────────────┼──────────────────┼────────────────────┼────────────────┼──────────────┤
# │ MLA1424712885 │ Notebook Exo Smart T38 Intel N4020 4gb Ssd128gb Windows 11 Color Gris                                                   │ new       │ MLA22826188        │ gold_pro        │ MLA1652     │ MLA-NOTEBOOKS │ 414399.26 │       559999.0 │                      │          414399.26 │                250 │  180214913 │ EXO SA           │ 1730421501.3225703 │ GCY1SBkSzYYtlA │ laptop       │
# │ MLA1867549266 │ Notebook Lenovo Ideapad 1 15iau7 Pantalla Táctil Fhd De 15,6 Pulgadas Core I3-1215u 8 Gb De Ram Ssd De 256 Gb Gris Nube │ new       │ MLA37834136        │ gold_pro        │ MLA1652     │ MLA-NOTEBOOKS │  889999.0 │      1313198.0 │                      │           889999.0 │                250 │  638528199 │ MULTI.HOGAR      │ 1730421501.3225703 │ nZOsXziZMoAYDA │ laptop       │
# └───────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────┴────────────────────┴─────────────────┴─────────────┴───────────────┴───────────┴────────────────┴──────────────────────┴────────────────────┴────────────────────┴────────────┴──────────────────┴────────────────────┴────────────────┴──────────────┘

# %%
base.sql('''
SELECT count(*)
FROM main_silver.search
''')
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │         3292 │
# └──────────────┘

# %%
base.sql('''
SELECT *
FROM main_silver.search_attributes
LIMIT 2
''')
# Out:
# ┌─────────┬────────────┬────────────────┬────────────────┬──────────────┐
# │   id    │ value_name │ _dlt_parent_id │    _dlt_id     │ product_type │
# │ varchar │  varchar   │    varchar     │    varchar     │   varchar    │
# ├─────────┼────────────┼────────────────┼────────────────┼──────────────┤
# │ BRAND   │ EXO        │ GCY1SBkSzYYtlA │ y2aFiuP69UZ3jA │ laptop       │
# │ COLOR   │ Gris       │ GCY1SBkSzYYtlA │ qjrcSESk/xdr5w │ laptop       │
# └─────────┴────────────┴────────────────┴────────────────┴──────────────┘

# %%
base.sql('''
SELECT COUNT(*)
FROM main_silver.search_attributes
''')
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │        25564 │
# └──────────────┘

# %%
base.sql('''
SELECT *
FROM main_silver.seller
LIMIT 2
''')
# Out:
# ┌───────────┬────────────────────────────┬────────────┬───────────────┬────────────────┬───────────┬─────────┬─────────────────────────────┬────────────────────────────────────────┬─────────────────────────────────────────┬────────────────────────────────────────┬─────────────────────┬────────────────────┬────────────────┬──────────────┐
# │    id     │          nickname          │ country_id │ address__city │ address__state │ user_type │ site_id │ seller_reputation__level_id │ seller_reputation__power_seller_status │ seller_reputation__transactions__period │ seller_reputation__transactions__total │ status__site_status │    _dlt_load_id    │    _dlt_id     │ product_type │
# │   int64   │          varchar           │  varchar   │    varchar    │    varchar     │  varchar  │ varchar │           varchar           │                varchar                 │                 varchar                 │                 int64                  │       varchar       │      varchar       │    varchar     │   varchar    │
# ├───────────┼────────────────────────────┼────────────┼───────────────┼────────────────┼───────────┼─────────┼─────────────────────────────┼────────────────────────────────────────┼─────────────────────────────────────────┼────────────────────────────────────────┼─────────────────────┼────────────────────┼────────────────┼──────────────┤
# │ 180214913 │ EXO SA                     │ AR         │ Boedo         │ AR-C           │ brand     │ MLA     │ 5_green                     │ platinum                               │ historic                                │                                  11878 │ active              │ 1730421501.3225703 │ 49hFFJ3EQLxaoA │ laptop       │
# │  82916233 │ MEXX GAMERS.POR.NATURALEZA │ AR         │ Caballito     │ AR-C           │ brand     │ MLA     │ 5_green                     │ platinum                               │ historic                                │                                  54374 │ active              │ 1730421501.3225703 │ 5Bc34IWr4FE0sA │ laptop       │
# └───────────┴────────────────────────────┴────────────┴───────────────┴────────────────┴───────────┴─────────┴─────────────────────────────┴────────────────────────────────────────┴─────────────────────────────────────────┴────────────────────────────────────────┴─────────────────────┴────────────────────┴────────────────┴──────────────┘

# %%
base.sql('''
SELECT COUNT(*)
FROM main_silver.seller
LIMIT 2
''')
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │         3292 │
# └──────────────┘

# %%
base.close()

# %% [markdown]
# ## 12). Crear los Modelos "Gold"

# %% [markdown]
# #### a). Crear una carpeta con el nombre "gold" dentro de la carpeta "models"

# %% [markdown]
# #### b). Modificar el archivo "dbt_project.yml"
#
# ```yaml
#     gold:
#       +schema: gold
# ```

# %% [markdown]
# ### c). Crear el modelo en .sql:

# %% [markdown]
# ```sql
# WITH productos_con_procesador_i7 AS
# (
# SELECT
#     _dlt_parent_id
#
# FROM {{ ref('search_attributes')}} a
# WHERE id = 'PROCESSOR_LINE'
# AND value_name = 'Core i7'
# )
#
#
# SELECT
#     a.id product_id,
#     a.title,
#     seller__nickname as vendedor,
#     a.product_type as tipo_de_producto,
#     seller_reputation__power_seller_status as reputacion,
#     condition,
#     address__state as provincia,
#     available_quantity as cantidad_disponible,
#     price as precio
#
#
# FROM {{ ref('search')}} a
# LEFT JOIN {{ ref('seller')}} b ON a.seller__id = b.id
#
# WHERE a._dlt_id IN (SELECT * FROM productos_con_procesador_i7)
# ```

# %% [markdown]
# ### d). Ejecutar el código de DBT para crear los modelos
# ```powershell
# 01-bases-de-datos-py3.11juan@BOOK-NFF0K06361:~/UCCuyo/BaseDeDatos2024/ml_transformations$ dbt run --select publicaciones_con_i7
# 16:19:34  Running with dbt=1.8.0
# 16:19:34  Registered adapter: duckdb=1.9.0
# 16:19:35  Found 6 models, 4 data tests, 9 sources, 416 macros
# 16:19:35
# 16:19:35  Concurrency: 1 threads (target='dev')
# 16:19:35
# 16:19:35  1 of 1 START sql view model main_gold.publicaciones_con_i7 ..................... [RUN]
# 16:19:36  1 of 1 OK created sql view model main_gold.publicaciones_con_i7 ................ [OK in 0.31s]
# 16:19:36
# 16:19:36  Finished running 1 view model in 0 hours 0 minutes and 0.94 seconds (0.94s).
# 16:19:36
# 16:19:36  Completed successfully
# 16:19:36
# 16:19:36  Done. PASS=1 WARN=0 ERROR=0 SKIP=0 TOTAL=1
# ```

# %% [markdown]
# ## 14). Subir la base a MotherDuck

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

motherduck_token = os.getenv('MOTHER_DUCK_TOKEN')

nombre_bd_motherduck = 'mercado_libre'

ruta_bd_local = 'mercado_libre.duckdb'

con = duckdb.connect(f"md:?motherduck_token={motherduck_token}")

# Crea la base de datos en MotherDuck a partir de la base de datos local
con.execute(f"CREATE DATABASE {nombre_bd_motherduck} FROM '{ruta_bd_local}'")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %% [markdown]
# # 3. Extra
#
# ## Extensión de VSCODE
#
# ![image.png](attachment:image.png)
#
# ## Lineage
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 2). Funcionalidades Extra de DBT:

# %% [markdown]
# ## 3). Proyecto desde 0

# %%
import requests

url = "https://data.alpaca.markets/v1beta3/crypto/us/bars?symbols=BTC%2FUSD%2CLTC%2FUSD&timeframe=1Min&start=2024-11-01&limit=1000&sort=asc"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"bars":{"BTC/USD":[{"c":70185.09,"h":70185.09,"l":70185.09,"n":0,"o":70185.09,"t":"2024-11-01T00:00:00Z","v":0,"vw":0},{"c":70229.17,"h":70229.17,"l":70229.17,"n":0,"o":70229.17,"t":"2024-11-01T00:03:00Z","v":0,"vw":0},{"c":70308.255,"h":70308.255,"l":70269.155,"n":0,"o":70269.155,"t":"2024-11-01T00:05:00Z","v":0,"vw":0},{"c":70326,"h":70341.9995,"l":70326,"n":0,"o":70341.9995,"t":"2024-11-01T00:07:00Z","v":0,"vw":0},{"c":70321.8335,"h":70321.8335,"l":70321.8335,"n":0,"o":70321.8335,"t":"2024-11-01T00:08:00Z","v":0,"vw":0},{"c":70281.435,"h":70281.435,"l":70281.435,"n":0,"o":70281.435,"t":"2024-11-01T00:09:00Z","v":0,"vw":0},{"c":70241.4,"h":70297.595,"l":70241.4,"n":0,"o":70289.85,"t":"2024-11-01T00:10:00Z","v":0,"vw":0},{"c":70262.388,"h":70262.388,"l":70262.388,"n":0,"o":70262.388,"t":"2024-11-01T00:12:00Z","v":0,"vw":0},{"c":70363.8415,"h":70363.8415,"l":70350.205,"n":0,"o":70350.205,"t":"2024-11-01T00:14:00Z","v":0,"vw":0},{"c":70341.05,"h":70356.265,"l":70341.05,"n":0,"o":70356.265,"t":"2024-11-01T00:15:00Z","v":0,"vw":0},{"c":70327.399,"h":70327.399,"l":70311.09,"n":0,"o":70311.09,"t":"2024-11-01T00:17:00Z","v":0,"vw":0},{"c":70336.2585,"h":70358.1825,"l":70336.2585,"n":0,"o":70358.1825,"t":"2024-11-01T00:20:00Z","v":0,"vw":0},{"c":70329.051,"h":70329.051,"l":70329.051,"n":0,"o":70329.051,"t":"2024-11-01T00:25:00Z","v":0,"vw":0},{"c":70359.105,"h":70359.105,"l":70297.35,"n":0,"o":70297.35,"t":"2024-11-01T00:27:00Z","v":0,"vw":0},{"c":70279.415,"h":70279.415,"l":70275.705,"n":0,"o":70275.705,"t":"2024-11-01T00:31:00Z","v":0,"vw":0},{"c":70215.545,"h":70215.545,"l":70202.09,"n":0,"o":70202.09,"t":"2024-11-01T00:33:00Z","v":0,"vw":0},{"c":70183.1815,"h":70183.1815,"l":70183.1815,"n":0,"o":70183.1815,"t":"2024-11-01T00:34:00Z","v":0,"vw":0},{"c":70145.1,"h":70145.1,"l":70145.1,"n":0,"o":70145.1,"t":"2024-11-01T00:35:00Z","v":0,"vw":0},{"c":70114.06,"h":70114.06,"l":70114.06,"n":0,"o":70114.06,"t":"2024-11-01T00:36:00Z","v":0,"vw":0},{"c":70102.3,"h":70102.3,"l":70102.3,"n":0,"o":70102.3,"t":"2024-11-01T00:38:00Z","v":0,"vw":0},{"c":70054.497,"h":70054.497,"l":70054.497,"n":0,"o":70054.497,"t":"2024-11-01T00:39:00Z","v":0,"vw":0},{"c":70130.89,"h":70130.89,"l":70104.955,"n":0,"o":70104.955,"t":"2024-11-01T00:41:00Z","v":0,"vw":0},{"c":70198.442,"h":70198.442,"l":70168.245,"n":0,"o":70168.245,"t":"2024-11-01T00:42:00Z","v":0,"vw":0},{"c":70159.9935,"h":70159.9935,"l":70159.9935,"n":0,"o":70159.9935,"t":"2024-11-01T00:46:00Z","v":0,"vw":0},{"c":70251.715,"h":70251.715,"l":70251.715,"n":0,"o":70251.715,"t":"2024-11-01T00:47:00Z","v":0,"vw":0},{"c":70245.8025,"h":70245.8025,"l":70245.8025,"n":0,"o":70245.8025,"t":"2024-11-01T00:48:00Z","v":0,"vw":0},{"c":70273.915,"h":70278.715,"l":70233.22,"n":1,"o":70233.22,"t":"2024-11-01T00:49:00Z","v":0.0129675,"vw":70233.22},{"c":70219.27,"h":70231.86,"l":70217.865,"n":0,"o":70231.86,"t":"2024-11-01T00:51:00Z","v":0,"vw":0},{"c":70227.18,"h":70227.18,"l":70227.18,"n":0,"o":70227.18,"t":"2024-11-01T00:52:00Z","v":0,"vw":0},{"c":70190.2015,"h":70190.2015,"l":70190.2015,"n":0,"o":70190.2015,"t":"2024-11-01T00:53:00Z","v":0,"vw":0},{"c":70186.04,"h":70186.04,"l":70181.0115,"n":0,"o":70181.0115,"t":"2024-11-01T00:54:00Z","v":0,"vw":0},{"c":70154.075,"h":70154.075,"l":70154.075,"n":0,"o":70154.075,"t":"2024-11-01T00:55:00Z","v":0,"vw":0},{"c":70164.955,"h":70164.955,"l":70151.915,"n":0,"o":70151.915,"t":"2024-11-01T00:56:00Z","v":0,"vw":0},{"c":70138.548,"h":70157.61,"l":70123.97,"n":0,"o":70157.61,"t":"2024-11-01T00:57:00Z","v":0,"vw":0},{"c":70105.825,"h":70105.825,"l":70105.825,"n":0,"o":70105.825,"t":"2024-11-01T00:58:00Z","v":0,"vw":0},{"c":70087.14,"h":70087.14,"l":70067.2225,"n":0,"o":70067.2225,"t":"2024-11-01T00:59:00Z","v":0,"vw":0},{"c":70124.122,"h":70124.122,"l":70123.205,"n":0,"o":70123.205,"t":"2024-11-01T01:03:00Z","v":0,"vw":0},{"c":70121.7835,"h":70121.7835,"l":70121.7835,"n":0,"o":70121.7835,"t":"2024-11-01T01:05:00Z","v":0,"vw":0},{"c":70118.5745,"h":70118.5745,"l":70118.574 ...
